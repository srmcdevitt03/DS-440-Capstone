# %%
import pandas as pd
import functools
conversions = pd.read_csv("/Users/stephenmcdevitt/DS-440-Capstone/datasets/conversions.csv")
conversions_against = pd.read_csv("/Users/stephenmcdevitt/DS-440-Capstone/datasets/conversionsagainst.csv")
drive_averages = pd.read_csv("/Users/stephenmcdevitt/DS-440-Capstone/datasets/driveaverages.csv")
drive_averages_against = pd.read_csv("/Users/stephenmcdevitt/DS-440-Capstone/datasets/driveaveragesagainst.csv")
kick_and_punt_returns_against = pd.read_csv("/Users/stephenmcdevitt/DS-440-Capstone/datasets/kickandpuntreturnagainst.csv")
kick_and_punt_returns = pd.read_csv("/Users/stephenmcdevitt/DS-440-Capstone/datasets/kickandpuntreturns.csv")
kicking = pd.read_csv("/Users/stephenmcdevitt/DS-440-Capstone/datasets/kickingagainst.csv")
passing_against = pd.read_csv("/Users/stephenmcdevitt/DS-440-Capstone/datasets/passingdefense.csv")
passing = pd.read_csv("/Users/stephenmcdevitt/DS-440-Capstone/datasets/passingoffense.csv")
punting = pd.read_csv("/Users/stephenmcdevitt/DS-440-Capstone/datasets/punting.csv")
punting_against = pd.read_csv("/Users/stephenmcdevitt/DS-440-Capstone/datasets/puntingagainst.csv")
rushing_against = pd.read_csv("/Users/stephenmcdevitt/DS-440-Capstone/datasets/rushingdefense.csv")
rushing = pd.read_csv("/Users/stephenmcdevitt/DS-440-Capstone/datasets/rushingoffense.csv")
scoring_defense = pd.read_csv("/Users/stephenmcdevitt/DS-440-Capstone/datasets/scoringdefense.csv")
scoring_offense = pd.read_csv("/Users/stephenmcdevitt/DS-440-Capstone/datasets/scoringoffense.csv")
team_advanced_defense =pd.read_csv("/Users/stephenmcdevitt/DS-440-Capstone/datasets/teamadvanceddefense.csv") 
team_defense_statistics = pd.read_csv("/Users/stephenmcdevitt/DS-440-Capstone/datasets/teamdefensestatistics.csv")
team_offense = pd.read_csv("/Users/stephenmcdevitt/DS-440-Capstone/datasets/teamoffense.csv")

# %%
conversions.columns = [
    "Rk_conversions", "Tm", "G", "3DAtt", "3DConv", "3D%", 
    "4DAtt", "4DConv", "4D%", "RZAtt", "RZTD", "RZPct"
]

# Display first few rows to confirm
conversions_1 = conversions.drop(index=0).reset_index(drop=True)
print(conversions_1.head())
# Out:
#   Rk_conversions                    Tm  G 3DAtt 3DConv    3D% 4DAtt 4DConv  \
# 0              1   San Francisco 49ers  5    70     32  45.7%     8      6
# 1              2  Los Angeles Chargers  5    69     32  46.4%     5      3
# 2              3       New York Giants  6    81     32  39.5%    14      6
# 3              4     Green Bay Packers  4    54     29  53.7%     3      2
# 4              5        Miami Dolphins  5    60     28  46.7%     7      4
#
#      4D% RZAtt RZTD  RZPct
# 0  75.0%    19    8  42.1%
# 1  60.0%    13    5  38.5%
# 2  42.9%    22    9  40.9%
# 3  66.7%    17   12  70.6%
# 4  57.1%    13   10  76.9%

# %%
conversions_against.columns = [
    "Rk_conversions_against", "Tm", "G", "3DAtt_against", "3DConv_against", "3D%_against", 
    "4DAtt_against", "4DConv_against", "4D%_against", "RZAtt_against", "RZTD_against", "RZPct_against"
]

conversions_against_1 = conversions_against.drop(index=0).reset_index(drop=True)
print(conversions_against_1.head())
# Out:
#   Rk_conversions_against                   Tm  G 3DAtt_against 3DConv_against  \
# 0                      1        Chicago Bears  4            41             12
# 1                      2      Atlanta Falcons  4            44             15
# 2                      3    Green Bay Packers  4            55             18
# 3                      4    Minnesota Vikings  5            63             19
# 4                      5  San Francisco 49ers  5            60             20
#
#   3D%_against 4DAtt_against 4DConv_against 4D%_against RZAtt_against  \
# 0       29.3%             5              3       60.0%            17
# 1       34.1%             7              6       85.7%             6
# 2       32.7%            10              6       60.0%            12
# 3       30.2%             5              3       60.0%            16
# 4       33.3%             8              6       75.0%            16
#
#   RZTD_against RZPct_against
# 0           11         64.7%
# 1            4         66.7%
# 2            7         58.3%
# 3            8         50.0%
# 4            9         56.3%

# %%
#drive_averages

# %%
drive_averages.columns = [
    "Rk_drive_averages", "Tm", "G", "#Dr", "Plays", "Sc%", 
    "TO%", "Avg_plays", "Avg_yards", "Avg_start", "Avg_time", "Avg_pts"
]

drive_averages_1 = drive_averages.drop(index=0).reset_index(drop=True)
print(drive_averages_1.head())
# Out:
#   Rk_drive_averages                   Tm  G #Dr Plays   Sc%   TO% Avg_plays  \
# 0                 1  Philadelphia Eagles  6  62   341  33.9   4.8       5.5
# 1                 2      New York Giants  6  61   402  36.1  13.1       6.6
# 2                 3     Cleveland Browns  5  58   340  24.1  13.8       5.9
# 3                 4    Minnesota Vikings  5  57   295  35.1  14.0       5.2
# 4                 5     Tennessee Titans  5  57   312  29.8  12.3       5.5
#
#   Avg_yards Avg_start Avg_time Avg_pts
# 0      24.9  Own 27.2     2:48    1.98
# 1      32.2  Own 33.1     3:07    2.00
# 2      24.8  Own 29.6     2:41    1.28
# 3      26.9  Own 27.9     2:32    1.89
# 4      20.5  Own 30.7     2:26    1.18

# %%
drive_averages_against.columns = [
    "Rk_drive_averages_against", "Tm", "G", "#Dr_against", "Plays_against", "Sc%_against", 
    "TO%_against", "Avg_plays_against", "Avg_yards_against", "Avg_start_against", "Avg_time_against", "Avg_pts_against"
]

drive_averages_against_1 = drive_averages_against.drop(index=0).reset_index(drop=True)
print(drive_averages_against_1.head())
# Out:
#   Rk_drive_averages_against                   Tm  G #Dr_against Plays_against  \
# 0                         1      Atlanta Falcons  4          38           219
# 1                         2  Pittsburgh Steelers  4          40           275
# 2                         3    Green Bay Packers  4          40           262
# 3                         4       Miami Dolphins  5          45           316
# 4                         5        Chicago Bears  4          46           234
#
#   Sc%_against TO%_against Avg_plays_against Avg_yards_against  \
# 0        44.7        10.5               5.8              25.7
# 1          40        22.5               6.9              38.4
# 2        37.5           5               6.6              28.3
# 3        57.8         8.9                 7              42.6
# 4        43.5        19.6               5.1                33
#
#   Avg_start_against Avg_time_against Avg_pts_against
# 0          Own 33.5             2:47            2.08
# 1          Own 27.5             3:19             2.3
# 2          Own 30.9             3:05            2.03
# 3          Own 26.5             3:39            3.07
# 4          Own 30.7             2:33            2.52

# %%
kick_and_punt_returns_against.columns = ["Rk_kick_and_punt_returns_against", "Tm", "G", "Punt_Returns_Against", 
                                         "Punt_return_yds_against", "Punt_return_TD_against", "Punt_return_Y/R_against", "Kick_return_against", 
                                         "Kick_return_yds_against", "Kick_return_TD_against", "Kick_return_Y/Rt_against"]

kick_and_punt_returns_against_1 = kick_and_punt_returns_against.drop(index=0).reset_index(drop=True)
print(kick_and_punt_returns_against_1.head())
# Out:
#   Rk_kick_and_punt_returns_against                    Tm  G  \
# 0                                1   Philadelphia Eagles  6
# 1                                2       New York Giants  6
# 2                                3         Detroit Lions  5
# 3                                4         Buffalo Bills  5
# 4                                5  Tampa Bay Buccaneers  5
#
#   Punt_Returns_Against Punt_return_yds_against Punt_return_TD_against  \
# 0                   19                     265                      0
# 1                   10                      47                      0
# 2                   10                      85                      0
# 3                    6                      49                      0
# 4                    6                      99                      0
#
#   Punt_return_Y/R_against Kick_return_against Kick_return_yds_against  \
# 0                    13.9                  27                     593
# 1                     4.7                  25                     542
# 2                     8.5                  25                     642
# 3                     8.2                  28                     739
# 4                    16.5                  27                     733
#
#   Kick_return_TD_against Kick_return_Y/Rt_against
# 0                      0                       22
# 1                      0                     21.7
# 2                      0                     25.7
# 3                      0                     26.4
# 4                      0                     27.1

# %%
kick_and_punt_returns.columns = ["Rk_kick_and_punt_returns", "Tm", "G", "Punt_Returns", 
                                         "Punt_return_yds", "Punt_return_TD", "Punt_return_lng", "Punt_return_Y/R", "Kick_return", 
                                         "Kick_return_yds", "Kick_return_TD", "Kick_return_lng", "Kick_return_Y/Rt", "Kick_return_APYd"]

kick_and_punt_returns_1 = kick_and_punt_returns.drop(index=0).reset_index(drop=True)
print(kick_and_punt_returns_1.head())
# Out:
#   Rk_kick_and_punt_returns                     Tm  G Punt_Returns  \
# 0                        1      Minnesota Vikings  5           17
# 1                        2        New York Giants  6           13
# 2                        3         Denver Broncos  5           13
# 3                        4       Los Angeles Rams  5           12
# 4                        5  Washington Commanders  5           12
#
#   Punt_return_yds Punt_return_TD Punt_return_lng Punt_return_Y/R Kick_return  \
# 0             170              0              29            10.0          23
# 1             121              0              21             9.3          26
# 2             169              0              32            13.0          19
# 3             109              0              20             9.1          20
# 4             177              1              90            14.8          18
#
#   Kick_return_yds Kick_return_TD Kick_return_lng Kick_return_Y/Rt  \
# 0             578              0              34             25.1
# 1             706              0              46             27.2
# 2             486              0              32             25.6
# 3             499              0              32             25.0
# 4             598              0              69             33.2
#
#   Kick_return_APYd
# 0             2565
# 1             3035
# 2             2461
# 3             2648
# 4             2610

# %%
#kicking

# %%
kicking.columns = ["Rk_FG", "Tm", "G", "FGA", "FGM", "FG%", "XPA", "XPM", "XP%"]

kicking_1 = kicking.drop(index=0).reset_index(drop=True)
print(kicking_1.head())
# Out:
#   Rk_FG                   Tm  G FGA FGM    FG% XPA XPM     XP%
# 0     1   Cincinnati Bengals  5   6   5  83.3%  20  19   95.0%
# 1     2     Cleveland Browns  5   8   6  75.0%  15  15  100.0%
# 2     3        New York Jets  5  14  13  92.9%  17  16   94.1%
# 3     4       Miami Dolphins  5  12  11  91.7%  14  12   85.7%
# 4     5  Pittsburgh Steelers  4   6   5  83.3%   9   9  100.0%

# %%
#passing_against

# %%
passing_against.columns = ["Rk_passing_defense", "Tm", "G", 
                           "Cmp_allowed", "Att_allowed_passing", "Cmp%_allowed", 
                           "Passing_yds_allowed", "Passing_TDs_allowed", 
                           "Passing_TD%_allowed", "Int", "Passes_defended", 
                           "Int%", "Y/A_passing_allowed", "AY/A_passing_allowed", 
                           "Y/C_passing_allowed", "Y/G_passing_allowed", "Rate_allowed", "Sk", 
                           "SkYds", "QBHits", "TFL", "Sk%", "NY/A_passing_allowed", "NY/A_passing_allowed", "EXP_passing_defense"]

passing_against_1 = passing_against
passing_against_1.head()
# Out:
#    Rk_passing_defense                 Tm  G  Cmp_allowed  Att_allowed_passing  \
# 0                   1    Atlanta Falcons  4           60                  104
# 1                   2      Buffalo Bills  5           86                  133
# 2                   3  Minnesota Vikings  5           90                  138
# 3                   4  Green Bay Packers  4          107                  157
# 4                   5      Chicago Bears  4           84                  114
#
#    Cmp%_allowed  Passing_yds_allowed  Passing_TDs_allowed  \
# 0          57.7                  540                    5
# 1          64.7                  770                    6
# 2          65.2                  788                    5
# 3          68.2                  823                    6
# 4          73.7                  860                   10
#
#    Passing_TD%_allowed  Int  ...  Y/G_passing_allowed  Rate_allowed  Sk  \
# 0                  4.8  3.0  ...                135.0          78.3  10
# 1                  4.5  2.0  ...                154.0          91.0  13
# 2                  3.6  2.0  ...                157.6          88.9  13
# 3                  3.8  2.0  ...                205.8          89.8  11
# 4                  8.8  7.0  ...                215.0          99.5   5
#
#    SkYds  QBHits  TFL  Sk%  NY/A_passing_allowed  NY/A_passing_allowed  \
# 0     62      23   15  8.8                   4.7                   4.4
# 1     67      24   26  8.9                   5.3                   5.5
# 2     87      23   28  8.6                   5.2                   5.3
# 3     63      35   18  6.5                   4.9                   5.1
# 4     26      17   17  4.2                   7.2                   6.3
#
#    EXP_passing_defense
# 0                 0.24
# 1                -0.83
# 2                35.46
# 3               -15.10
# 4               -21.75
#
# [5 rows x 25 columns]

# %%
passing.columns = ["Rk_passing", "Tm", "G", 
                   "Cmp", "Passing_Att", "Cmp%", "Passing_yds", 
                   "Passing_tds", "Passing_td%", "Int_thrown", "Int%_thrown", 
                   "Passing_lng", "Y/A_passing", "AY/A_passing", "Y/C_passing", 
                   "Y/G_passing", "rate", "Sk_allowed", "SkYds_allowed", "Sk%_allowed", 
                   "NY/A_passing", "ANY/A_passing", "4QC", "GWD", "EXP_passing"]
passing_1=passing
passing_1.head()
# Out:
#    Rk_passing                   Tm  G  Cmp  Passing_Att  Cmp%  Passing_yds  \
# 0           1  San Francisco 49ers  5  134          202  66.3         1453
# 1           2     Los Angeles Rams  5  122          184  66.3         1448
# 2           3       Dallas Cowboys  5  142          200  71.0         1361
# 3           4   Indianapolis Colts  5  108          153  70.6         1265
# 4           5     Seattle Seahawks  5  100          137  73.0         1227
#
#    Passing_tds  Passing_td%  Int_thrown  ...  Y/G_passing   rate  Sk_allowed  \
# 0           10          5.0           5  ...        290.6   94.3           7
# 1           11          6.0           2  ...        289.6  106.8           9
# 2           10          5.0           4  ...        272.2   98.7           7
# 3            6          3.9           2  ...        253.0  103.9           4
# 4            9          6.6           3  ...        245.4  114.0           6
#
#    SkYds_allowed  Sk%_allowed  NY/A_passing  ANY/A_passing  4QC  GWD  \
# 0             38          3.3           7.0            6.8  2.0  3.0
# 1             55          4.7           7.5            8.2  1.0  1.0
# 2             36          3.4           6.6            6.7  2.0  1.0
# 3             34          2.5           8.1            8.2  1.0  1.0
# 4             34          4.2           8.6            8.9  0.0  2.0
#
#    EXP_passing
# 0        51.23
# 1        52.87
# 2        59.43
# 3        65.02
# 4        59.66
#
# [5 rows x 25 columns]

# %%
punting.columns = ["punting_rk", "Tm", "G", "Pnt", 
                   "Pnt_Yds_total", "Y/P", "RetYds", "Net", 
                   "NY/P", "Lng", "TB", "TB%", "In20", "In20%", "Blk_allowed"]

punting_1 = punting.drop(index=0).reset_index(drop=True)
print(punting_1.head())
# Out:
#   punting_rk                   Tm  G Pnt Pnt_Yds_total   Y/P RetYds   Net  \
# 0          1     Cleveland Browns  5  29          1285  44.3    145  1080
# 1          2  Philadelphia Eagles  6  30          1578  52.6    265  1253
# 2          3   Cincinnati Bengals  5  27          1433  53.1    163  1150
# 3          4     Tennessee Titans  5  24          1181  49.2     92  1045
# 4          5    Minnesota Vikings  5  24          1179  49.1     86  1093
#
#    NY/P Lng TB    TB% In20  In20% Blk_allowed
# 0  36.0  58  4  13.8%   11  37.9%           1
# 1  41.8  70  3  10.0%    6  20.0%           0
# 2  42.6  70  6  22.2%    7  25.9%           0
# 3  43.5  65  2   8.3%    9  37.5%           0
# 4  45.5  77  0   0.0%    6  25.0%           0

# %%
punting_against.columns = ["Punting_against_rk", "Tm", "G", "Pnt_against", "Pnt_Yds_against", "Y/P_against", "Blk"]

punting_against_1 = punting_against.drop(index=0).reset_index(drop=True)
print(punting_against_1.head())
# Out:
#   Punting_against_rk                  Tm  G Pnt_against Pnt_Yds_against  \
# 0                  1  Indianapolis Colts  5          11             469
# 1                  2     Atlanta Falcons  4          13             633
# 2                  3       Buffalo Bills  5          21            1025
# 3                  4  Kansas City Chiefs  5          12             596
# 4                  5   Green Bay Packers  4          17             810
#
#   Y/P_against Blk
# 0        42.6   1
# 1        48.7   0
# 2        48.8   0
# 3        49.7   0
# 4        47.6   0

# %%
rushing_against.columns = ["Rk_rushing_allowed", "Tm", "G", "Rushing_att_allowed", 
                           "Rushing_Yds_allowed", "Rushing_Tds_allowed", "Y/A_rushing_allowed", "Y/G_rushing_allowed", "EXP_rushing_allowed"]

rushing_against_1 = rushing_against

# %%
rushing.columns = ["Rk_rushing", "Tm", "G", "Rushing_Att", "Rushing_yds", "Rushing_tds", "Lng_rushing", 
                   "Y/A_rushing", "Y/G_rushing", "Fmb", "EXP_rushing"]

rushing_1 = rushing
rushing_1.head()
# Out:
#    Rk_rushing                     Tm  G  Rushing_Att  Rushing_yds  \
# 0           1  Washington Commanders  5          133          782
# 1           2          Buffalo Bills  5          162          772
# 2           3        New York Giants  6          181          757
# 3           4          New York Jets  5          133          722
# 4           5         Denver Broncos  5          142          703
#
#    Rushing_tds  Lng_rushing  Y/A_rushing  Y/G_rushing  Fmb  EXP_rushing
# 0            7           60          5.9        156.4    6        21.43
# 1            9           44          4.8        154.4    6        16.44
# 2            7           24          4.2        126.2    7         7.66
# 3            4           43          5.4        144.4    9         2.60
# 4            6           50          5.0        140.6    2         0.88

# %%
scoring_defense.columns = ["Rk_scoring_defense", "Tm", "G", "RshTD_allowed", 
                           "RecTD_allowed", "PR_TD_allowed", "KR_TD_allowed", "FblTD_allowed", 
                           "IntTD_allowed", "OthTD_allowed", "AllTD_allowed", "2PM_allowed", "2PA_allowed", 
                           "D2P_allowed", "XPM_allowed", "XPA_allowed", "FGM_allowed", "FGA_allowed", 
                           "Sfty_allowed", "Pts_allowed", "Pts/G_allowed"]

scoring_defense_1 = scoring_defense
scoring_defense_1.head()
# Out:
#    Rk_scoring_defense                  Tm  G  RshTD_allowed  RecTD_allowed  \
# 0                   1      Houston Texans  5              5              3
# 1                   2      Denver Broncos  5              2              4
# 2                   3  Indianapolis Colts  5              2              8
# 3                   4   Arizona Cardinals  5              3              5
# 4                   5   Minnesota Vikings  5              4              5
#
#    PR_TD_allowed  KR_TD_allowed  FblTD_allowed  IntTD_allowed  OthTD_allowed  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            1.0            NaN            NaN
# 4            NaN            NaN            NaN            1.0            NaN
#
#    ...  2PM_allowed  2PA_allowed  D2P_allowed  XPM_allowed  XPA_allowed  \
# 0  ...          NaN            1          NaN            7            7
# 1  ...          NaN            0          NaN            6            6
# 2  ...          1.0            1          NaN            9            9
# 3  ...          NaN            2          NaN            6            7
# 4  ...          NaN            0          NaN           10           10
#
#    FGM_allowed  FGA_allowed  Sfty_allowed  Pts_allowed  Pts/G_allowed
# 0            2            7           NaN           61           12.2
# 1           14           14           NaN           84           16.8
# 2            6           10           NaN           89           17.8
# 3           12           14           NaN           96           19.2
# 4            9           11           NaN           97           19.4
#
# [5 rows x 21 columns]

# %%
scoring_offense.columns = ["Rk_scoring_offense", "Tm", "G", "RshTd", 
                           "RecTd", "PR_TD", "KR_TD", "FblTD", "IntTD", 
                           "OthTD", "AllTD", "2PM", "2PA", "D2P", "XPM", "XPA", 
                           "FGM", "FGA", "Sfty", "Pts", "Pts/G"]

scoring_offense_1 = scoring_offense
scoring_offense_1.head()
# Out:
#    Rk_scoring_offense                  Tm    G  RshTd  RecTd  PR_TD  KR_TD  \
# 0                 1.0      Houston Texans  5.0    3.0    8.0    NaN    NaN
# 1                 2.0      Denver Broncos  5.0    6.0    8.0    NaN    NaN
# 2                 3.0  Indianapolis Colts  5.0   11.0    6.0    NaN    NaN
# 3                 4.0   Arizona Cardinals  5.0    4.0    6.0    NaN    NaN
# 4                 5.0   Minnesota Vikings  5.0    4.0    8.0    NaN    NaN
#
#    FblTD  IntTD  OthTD  ...  2PM  2PA  D2P   XPM   XPA   FGM   FGA  Sfty  \
# 0    NaN    NaN    NaN  ...  NaN  2.0  NaN   9.0   9.0  11.0  13.0   NaN
# 1    NaN    NaN    NaN  ...  1.0  1.0  NaN  13.0  13.0   6.0   7.0   NaN
# 2    NaN    1.0    NaN  ...  1.0  4.0  NaN  14.0  14.0  13.0  14.0   NaN
# 3    1.0    NaN    NaN  ...  NaN  0.0  NaN  11.0  11.0   8.0  10.0   1.0
# 4    1.0    1.0    NaN  ...  2.0  3.0  NaN  11.0  11.0   8.0   9.0   NaN
#
#      Pts  Pts/G
# 0  108.0   21.6
# 1  117.0   23.4
# 2  163.0   32.6
# 3  103.0   20.6
# 4  123.0   24.6
#
# [5 rows x 21 columns]

# %%
team_advanced_defense.columns = ["Tm", "G", "Att_allowed_passing", 
                                 "Cmp_allowed_passing", "Yds_allowed_passing", 
                                 "TD_allowed_passing", "DADOT", "Air_yards_Cmp", "YAC_allowed", 
                                 "Bltz", "Bltz%", "Hrry", "Hrry%", "QBKD", "QBKD%", "Sk", "Prss", "Prss%", "MTkl"]

team_advanced_defense_1 = team_advanced_defense
team_advanced_defense_1.head()
# Out:
#                    Tm  G  Att_allowed_passing  Cmp_allowed_passing  \
# 0     Atlanta Falcons  4                  104                   60
# 1       Buffalo Bills  5                  133                   86
# 2   Carolina Panthers  5                  153                  100
# 3       Chicago Bears  4                  114                   84
# 4  Cincinnati Bengals  5                  177                  120
#
#    Yds_allowed_passing  TD_allowed_passing  DADOT  Air_yards_Cmp  YAC_allowed  \
# 0                  540                   5    9.8            416          186
# 1                  770                   6    6.8            450          386
# 2                 1022                   7    7.8            568          472
# 3                  860                  10    6.8            444          442
# 4                 1295                  12    6.4            518          832
#
#    Bltz  Bltz%  Hrry  Hrry%  QBKD  QBKD%  Sk  Prss  Prss%  MTkl
# 0    46  37.1%     5   4.0%     9   8.7%  10    24  19.4%    12
# 1    40  25.2%    20  12.6%     6   4.5%  13    39  24.5%    23
# 2    29  17.2%     2   1.2%     6   3.9%   5    13   7.7%    26
# 3    21  17.1%     8   6.5%    12  10.5%   5    25  20.3%    34
# 4    32  16.6%    13   6.7%    11   6.2%  10    34  17.6%    49

# %%
team_defense_statistics.columns = ["Rk_team_defense", "Tm", "G", "PA", 
                                   "Yds_allowed", "Ply_allowed", "Y/P_allowed", 
                                   "Takeaways", "FL_forced", "1stD_allowed", "Cmp_allowed_passing", 
                                   "Att_allowed_passing", "Yds_allowed_passing", "TDs_allowed_passing", 
                                   "Int", "NY/A_allowed_passing", "1stD_allowed_passing", "Rushing_att_allowed", 
                                   "Rushing_Yds_allowed", "Rushing_Tds_allowed", "Y/A_rushing_allowed", "1stD_allowed_rushing", 
                                   "Pen_defense", "Pen_yds_defense", "1stPy_defense", "Sc%_allowed", "TO%", "EXP_allowed"]

team_defense_statistics_1 = team_defense_statistics.drop(index=0).reset_index(drop=True)
print(team_defense_statistics_1.head())
# Out:
#   Rk_team_defense                  Tm  G  PA Yds_allowed Ply_allowed  \
# 0               1      Houston Texans  5  61        1329         281
# 1               2      Denver Broncos  5  84        1443         300
# 2               3   Green Bay Packers  4  84        1133         254
# 3               4     Atlanta Falcons  4  86         976         208
# 4               5  Indianapolis Colts  5  89        1575         300
#
#   Y/P_allowed Takeaways FL_forced 1stD_allowed  ... Rushing_Yds_allowed  \
# 0         4.7         6         1           82  ...                 453
# 1         4.8         4         3           87  ...                 442
# 2         4.5         2         0           72  ...                 310
# 3         4.7         6         3           58  ...                 436
# 4         5.3         8         2          102  ...                 490
#
#   Rushing_Tds_allowed Y/A_rushing_allowed 1stD_allowed_rushing Pen_defense  \
# 0                   5                 3.9                   24          36
# 1                   2                 4.1                   19          47
# 2                   3                 3.6                   18          31
# 3                   2                 4.6                   22          25
# 4                   2                 4.5                   31          32
#
#   Pen_yds_defense 1stPy_defense Sc%_allowed   TO% EXP_allowed
# 0             259            11        19.2  11.5       16.72
# 1             344            16        35.1   5.3        9.93
# 2             255             7        37.5     5       -4.42
# 3             215             4        44.7  10.5       -2.14
# 4             294            13        34.8  17.4      -12.36
#
# [5 rows x 28 columns]

# %%
team_offense.columns = ["Rk_team_offense", "Tm", "G", "PF", "Yds", "Ply", 
                        "Y/P", "TO_allowed", "FL_allowed", "1stD", "Cmp_passing", 
                        "Att_passing", "Passing_Yds", "Passing_TDs", "Int_allowed", "NY/A_passing", 
                        "1stD_passing", "Rushing_Att", "Rushing_Yds", "RushingTDs", "Rushing_Y/A", 
                        "Rushing_1stD", "Pen_offense","Pen_Yds_offense", "1stPy_offense", "Sc%", "TO%_allowed", "EXP"]

team_offense_1 = team_offense.drop(index=0).reset_index(drop=True)
print(team_offense_1.head())
# Out:
#   Rk_team_offense                  Tm  G   PF   Yds  Ply  Y/P TO_allowed  \
# 0               1       Detroit Lions  5  174  1825  306    6          3
# 1               2  Indianapolis Colts  5  163  1906  303  6.3          3
# 2               3       Buffalo Bills  5  153  1979  324  6.1          4
# 3               4      Dallas Cowboys  5  151  2033  332  6.1          6
# 4               5    Seattle Seahawks  5  146  1792  286  6.3          8
#
#   FL_allowed 1stD  ... Rushing_Yds RushingTDs Rushing_Y/A Rushing_1stD  \
# 0          1  104  ...         674          8         4.4           37
# 1          1  116  ...         641         11         4.4           39
# 2          2  122  ...         772          9         4.8           43
# 3          2  125  ...         672          7         5.4           38
# 4          5  104  ...         565          6           4           33
#
#   Pen_offense Pen_Yds_offense 1stPy_offense   Sc% TO%_allowed    EXP
# 0          32             227             5  47.4         5.3  68.89
# 1          39             301            14  63.6         6.8  79.78
# 2          36             287            14  52.8         7.5  69.24
# 3          42             359            17    50        11.1  76.07
# 4          27             240            12    46          14   45.9
#
# [5 rows x 28 columns]

# %%
dfs = [
conversions_1, conversions_against_1, drive_averages_1,
drive_averages_against_1, kick_and_punt_returns_against_1, kick_and_punt_returns_1,
kicking_1, passing_against_1, passing_1, punting_1, punting_against_1,
rushing_against_1, rushing_1, scoring_defense_1, scoring_offense_1, 
team_advanced_defense_1, team_defense_statistics_1, team_offense_1
]

# for i, df in enumerate(dfs):
#     print(f"Dataset {i+1} G dtype:", df["G"].dtype)

# for df in dfs:
#     df["G"] = df["G"].astype(str)

for df in dfs:
    if "G" in df.columns:
        df.drop(columns=["G"], inplace=True)

merged_nfl_data = functools.reduce(
    lambda left, right: pd.merge(left, right, on="Tm", how="outer"),
    dfs
)

merged_nfl_data
# Out:
#    Rk_conversions                     Tm 3DAtt 3DConv    3D% 4DAtt 4DConv  \
# 0               1    San Francisco 49ers    70     32  45.7%     8      6
# 1               2   Los Angeles Chargers    69     32  46.4%     5      3
# 2               3        New York Giants    81     32  39.5%    14      6
# 3               4      Green Bay Packers    54     29  53.7%     3      2
# 4               5         Miami Dolphins    60     28  46.7%     7      4
# 5               6     Indianapolis Colts    58     27  46.6%     8      6
# 6               7      Arizona Cardinals    68     27  39.7%     4      4
# 7               8      Las Vegas Raiders    67     27  40.3%     9      4
# 8               9   Tampa Bay Buccaneers    65     27  41.5%     5      3
# 9              10     Kansas City Chiefs    65     27  41.5%    10      9
# 10             11          Buffalo Bills    59     26  44.1%     4      3
# 11             12       Cleveland Browns    76     26  34.2%    12      8
# 12             13      Carolina Panthers    66     26  39.4%    13      8
# 13             14    Philadelphia Eagles    75     26  34.7%     9      7
# 14             15     New Orleans Saints    68     26  38.2%     9      3
# 15             16         Dallas Cowboys    60     26  43.3%     6      4
# 16             17          Chicago Bears    55     25  45.5%     5      2
# 17             18         Denver Broncos    67     25  37.3%     5      2
# 18             19   Jacksonville Jaguars    63     24  38.1%     6      3
# 19             20          Detroit Lions    61     24  39.3%     9      7
# 20             21       Seattle Seahawks    55     24  43.6%     4      2
# 21             22        Atlanta Falcons    55     23  41.8%     8      4
# 22             23   New England Patriots    57     23  40.4%     8      7
# 23             24       Los Angeles Rams    57     23  40.4%     8      5
# 24             25     Cincinnati Bengals    61     22  36.1%     1      1
# 25             26          New York Jets    61     21  34.4%    13      7
# 26             27         Houston Texans    60     21  35.0%     7      6
# 27             28       Baltimore Ravens    52     21  40.4%     6      2
# 28             29       Tennessee Titans    69     20  29.0%     6      2
# 29             30      Minnesota Vikings    58     18  31.0%     6      4
# 30             31    Pittsburgh Steelers    44     17  38.6%     3      1
# 31             32  Washington Commanders    52     17  32.7%     6      4
# 32            NaN           League Total   NaN    NaN    NaN   NaN    NaN
# 33            NaN               Avg Team   NaN    NaN    NaN   NaN    NaN
# 34            NaN               Avg Tm/G   NaN    NaN    NaN   NaN    NaN
#
#        4D% RZAtt RZTD  ... Rushing_Yds RushingTDs Rushing_Y/A Rushing_1stD  \
# 0    75.0%    19    8  ...         426          0         3.1           25
# 1    60.0%    13    5  ...         584          2         4.9           30
# 2    42.9%    22    9  ...         757          7         4.2           54
# 3    66.7%    17   12  ...         458          4         3.8           25
# 4    57.1%    13   10  ...         411          2         4.2           19
# 5    75.0%    25   15  ...         641         11         4.4           39
# 6   100.0%    17   10  ...         591          4         4.8           26
# 7    44.4%    14    5  ...         563          2         4.4           29
# 8    60.0%    17    8  ...         552          3           4           29
# 9    90.0%    19   12  ...         600          6         4.8           42
# 10   75.0%    22   14  ...         772          9         4.8           43
# 11   66.7%    12    8  ...         479          3         3.9           32
# 12   61.5%    15   10  ...         640          3         4.8           32
# 13   77.8%    16   14  ...         572          8         3.5           43
# 14   33.3%    17    7  ...         584          2         4.1           34
# 15   66.7%    19   13  ...         672          7         5.4           38
# 16   40.0%    11    7  ...         409          3         3.8           26
# 17   40.0%    15   10  ...         703          6           5           34
# 18   50.0%    20   11  ...         685          6         4.9           37
# 19   77.8%    25   19  ...         674          8         4.4           37
# 20   50.0%    18   13  ...         565          6           4           33
# 21   50.0%    13    6  ...         546          4         4.3           31
# 22   87.5%    19   12  ...         476          6         3.7           32
# 23   62.5%    21   11  ...         561          3         4.6           34
# 24  100.0%    11    8  ...         285          2         3.1           18
# 25   53.8%    13    8  ...         722          4         5.4           41
# 26   85.7%    11    6  ...         581          3         4.4           31
# 27   33.3%    15    8  ...         578          6         5.5           27
# 28   33.3%     9    4  ...         426          2         3.8           26
# 29   66.7%    15   10  ...         534          4         4.5           29
# 30   33.3%    13    9  ...         320          3         3.3           26
# 31   66.7%    14   10  ...         782          7         5.9           38
# 32     NaN   NaN  NaN  ...         NaN        NaN         NaN          NaN
# 33     NaN   NaN  NaN  ...         NaN        NaN         NaN          NaN
# 34     NaN   NaN  NaN  ...         NaN        NaN         NaN          NaN
#
#    Pen_offense Pen_Yds_offense 1stPy_offense Sc%_y TO%_allowed     EXP
# 0           32             268            10  41.5        15.1   26.95
# 1           39             299            11    38          12    8.65
# 2           49             470            17  36.1        13.1    8.46
# 3           35             245            11  45.2         4.8   40.93
# 4           34             241             2  39.5        11.6   23.65
# 5           39             301            14  63.6         6.8   79.78
# 6           41             273             9    36          10   12.64
# 7           31             279             8  31.5        18.5  -10.45
# 8           35             306            16  47.2         3.8   41.03
# 9           42             350             6  51.1         4.3   46.25
# 10          36             287            14  52.8         7.5   69.24
# 11          37             307             8  24.1        13.8  -42.37
# 12          30             248            14    36          14    5.89
# 13          41             392            10  33.9         4.8   18.75
# 14          42             295            16    34         5.7    4.83
# 15          42             359            17    50        11.1   76.07
# 16          34             278             6  37.8         8.9    6.19
# 17          43             411            16  35.7         8.9   29.05
# 18          42             333             9    40        10.9   16.58
# 19          32             227             5  47.4         5.3   68.89
# 20          27             240            12    46          14    45.9
# 21          21             152             6  38.1        11.9    9.16
# 22          42             346             9  40.8        14.3   34.18
# 23          27             229            11  43.4        11.3    44.3
# 24          31             202            14  26.8        19.6  -38.64
# 25          42             352             9  38.5        11.5    0.26
# 26          34             267            13  43.1         9.8    16.2
# 27          31             194             8  45.3        13.2   23.45
# 28          41             331             7  29.8        12.3  -52.41
# 29          44             337             9  35.1          14   -6.73
# 30          19             135            11  38.6         6.8   15.09
# 31          37             271            13  46.9         6.1   41.05
# 32         NaN             NaN           NaN   NaN         NaN     NaN
# 33         NaN             NaN           NaN   NaN         NaN     NaN
# 34         NaN             NaN           NaN   NaN         NaN     NaN
#
# [35 rows x 256 columns]

# %%
merged_nfl_data = merged_nfl_data[
    ~merged_nfl_data["Tm"].isin(["League Total", "Avg Team", "Avg Tm/G"])
]

merged_nfl_data
# Out:
#    Rk_conversions                     Tm 3DAtt 3DConv    3D% 4DAtt 4DConv  \
# 0               1    San Francisco 49ers    70     32  45.7%     8      6
# 1               2   Los Angeles Chargers    69     32  46.4%     5      3
# 2               3        New York Giants    81     32  39.5%    14      6
# 3               4      Green Bay Packers    54     29  53.7%     3      2
# 4               5         Miami Dolphins    60     28  46.7%     7      4
# 5               6     Indianapolis Colts    58     27  46.6%     8      6
# 6               7      Arizona Cardinals    68     27  39.7%     4      4
# 7               8      Las Vegas Raiders    67     27  40.3%     9      4
# 8               9   Tampa Bay Buccaneers    65     27  41.5%     5      3
# 9              10     Kansas City Chiefs    65     27  41.5%    10      9
# 10             11          Buffalo Bills    59     26  44.1%     4      3
# 11             12       Cleveland Browns    76     26  34.2%    12      8
# 12             13      Carolina Panthers    66     26  39.4%    13      8
# 13             14    Philadelphia Eagles    75     26  34.7%     9      7
# 14             15     New Orleans Saints    68     26  38.2%     9      3
# 15             16         Dallas Cowboys    60     26  43.3%     6      4
# 16             17          Chicago Bears    55     25  45.5%     5      2
# 17             18         Denver Broncos    67     25  37.3%     5      2
# 18             19   Jacksonville Jaguars    63     24  38.1%     6      3
# 19             20          Detroit Lions    61     24  39.3%     9      7
# 20             21       Seattle Seahawks    55     24  43.6%     4      2
# 21             22        Atlanta Falcons    55     23  41.8%     8      4
# 22             23   New England Patriots    57     23  40.4%     8      7
# 23             24       Los Angeles Rams    57     23  40.4%     8      5
# 24             25     Cincinnati Bengals    61     22  36.1%     1      1
# 25             26          New York Jets    61     21  34.4%    13      7
# 26             27         Houston Texans    60     21  35.0%     7      6
# 27             28       Baltimore Ravens    52     21  40.4%     6      2
# 28             29       Tennessee Titans    69     20  29.0%     6      2
# 29             30      Minnesota Vikings    58     18  31.0%     6      4
# 30             31    Pittsburgh Steelers    44     17  38.6%     3      1
# 31             32  Washington Commanders    52     17  32.7%     6      4
#
#        4D% RZAtt RZTD  ... Rushing_Yds RushingTDs Rushing_Y/A Rushing_1stD  \
# 0    75.0%    19    8  ...         426          0         3.1           25
# 1    60.0%    13    5  ...         584          2         4.9           30
# 2    42.9%    22    9  ...         757          7         4.2           54
# 3    66.7%    17   12  ...         458          4         3.8           25
# 4    57.1%    13   10  ...         411          2         4.2           19
# 5    75.0%    25   15  ...         641         11         4.4           39
# 6   100.0%    17   10  ...         591          4         4.8           26
# 7    44.4%    14    5  ...         563          2         4.4           29
# 8    60.0%    17    8  ...         552          3           4           29
# 9    90.0%    19   12  ...         600          6         4.8           42
# 10   75.0%    22   14  ...         772          9         4.8           43
# 11   66.7%    12    8  ...         479          3         3.9           32
# 12   61.5%    15   10  ...         640          3         4.8           32
# 13   77.8%    16   14  ...         572          8         3.5           43
# 14   33.3%    17    7  ...         584          2         4.1           34
# 15   66.7%    19   13  ...         672          7         5.4           38
# 16   40.0%    11    7  ...         409          3         3.8           26
# 17   40.0%    15   10  ...         703          6           5           34
# 18   50.0%    20   11  ...         685          6         4.9           37
# 19   77.8%    25   19  ...         674          8         4.4           37
# 20   50.0%    18   13  ...         565          6           4           33
# 21   50.0%    13    6  ...         546          4         4.3           31
# 22   87.5%    19   12  ...         476          6         3.7           32
# 23   62.5%    21   11  ...         561          3         4.6           34
# 24  100.0%    11    8  ...         285          2         3.1           18
# 25   53.8%    13    8  ...         722          4         5.4           41
# 26   85.7%    11    6  ...         581          3         4.4           31
# 27   33.3%    15    8  ...         578          6         5.5           27
# 28   33.3%     9    4  ...         426          2         3.8           26
# 29   66.7%    15   10  ...         534          4         4.5           29
# 30   33.3%    13    9  ...         320          3         3.3           26
# 31   66.7%    14   10  ...         782          7         5.9           38
#
#    Pen_offense Pen_Yds_offense 1stPy_offense Sc%_y TO%_allowed     EXP
# 0           32             268            10  41.5        15.1   26.95
# 1           39             299            11    38          12    8.65
# 2           49             470            17  36.1        13.1    8.46
# 3           35             245            11  45.2         4.8   40.93
# 4           34             241             2  39.5        11.6   23.65
# 5           39             301            14  63.6         6.8   79.78
# 6           41             273             9    36          10   12.64
# 7           31             279             8  31.5        18.5  -10.45
# 8           35             306            16  47.2         3.8   41.03
# 9           42             350             6  51.1         4.3   46.25
# 10          36             287            14  52.8         7.5   69.24
# 11          37             307             8  24.1        13.8  -42.37
# 12          30             248            14    36          14    5.89
# 13          41             392            10  33.9         4.8   18.75
# 14          42             295            16    34         5.7    4.83
# 15          42             359            17    50        11.1   76.07
# 16          34             278             6  37.8         8.9    6.19
# 17          43             411            16  35.7         8.9   29.05
# 18          42             333             9    40        10.9   16.58
# 19          32             227             5  47.4         5.3   68.89
# 20          27             240            12    46          14    45.9
# 21          21             152             6  38.1        11.9    9.16
# 22          42             346             9  40.8        14.3   34.18
# 23          27             229            11  43.4        11.3    44.3
# 24          31             202            14  26.8        19.6  -38.64
# 25          42             352             9  38.5        11.5    0.26
# 26          34             267            13  43.1         9.8    16.2
# 27          31             194             8  45.3        13.2   23.45
# 28          41             331             7  29.8        12.3  -52.41
# 29          44             337             9  35.1          14   -6.73
# 30          19             135            11  38.6         6.8   15.09
# 31          37             271            13  46.9         6.1   41.05
#
# [32 rows x 256 columns]

# %%
merged_nfl_data.columns[merged_nfl_data.columns.duplicated()]
# Out:
# Index(['NY/A_passing_allowed'], dtype='object')

# %%
merged_nfl_data.columns.value_counts()
# Out:
# NY/A_passing_allowed    2
# Rk_conversions          1
# Pnt_against             1
# FGM_allowed             1
# FGA_allowed             1
#                        ..
# EXP_passing_defense     1
# Rk_passing              1
# Cmp                     1
# Passing_Att             1
# EXP                     1
# Name: count, Length: 255, dtype: int64

# %%
merged_nfl_data = merged_nfl_data.loc[:, ~merged_nfl_data.columns.duplicated()]

# %%
merged_nfl_data
# Out:
#    Rk_conversions                     Tm 3DAtt 3DConv    3D% 4DAtt 4DConv  \
# 0               1    San Francisco 49ers    70     32  45.7%     8      6
# 1               2   Los Angeles Chargers    69     32  46.4%     5      3
# 2               3        New York Giants    81     32  39.5%    14      6
# 3               4      Green Bay Packers    54     29  53.7%     3      2
# 4               5         Miami Dolphins    60     28  46.7%     7      4
# 5               6     Indianapolis Colts    58     27  46.6%     8      6
# 6               7      Arizona Cardinals    68     27  39.7%     4      4
# 7               8      Las Vegas Raiders    67     27  40.3%     9      4
# 8               9   Tampa Bay Buccaneers    65     27  41.5%     5      3
# 9              10     Kansas City Chiefs    65     27  41.5%    10      9
# 10             11          Buffalo Bills    59     26  44.1%     4      3
# 11             12       Cleveland Browns    76     26  34.2%    12      8
# 12             13      Carolina Panthers    66     26  39.4%    13      8
# 13             14    Philadelphia Eagles    75     26  34.7%     9      7
# 14             15     New Orleans Saints    68     26  38.2%     9      3
# 15             16         Dallas Cowboys    60     26  43.3%     6      4
# 16             17          Chicago Bears    55     25  45.5%     5      2
# 17             18         Denver Broncos    67     25  37.3%     5      2
# 18             19   Jacksonville Jaguars    63     24  38.1%     6      3
# 19             20          Detroit Lions    61     24  39.3%     9      7
# 20             21       Seattle Seahawks    55     24  43.6%     4      2
# 21             22        Atlanta Falcons    55     23  41.8%     8      4
# 22             23   New England Patriots    57     23  40.4%     8      7
# 23             24       Los Angeles Rams    57     23  40.4%     8      5
# 24             25     Cincinnati Bengals    61     22  36.1%     1      1
# 25             26          New York Jets    61     21  34.4%    13      7
# 26             27         Houston Texans    60     21  35.0%     7      6
# 27             28       Baltimore Ravens    52     21  40.4%     6      2
# 28             29       Tennessee Titans    69     20  29.0%     6      2
# 29             30      Minnesota Vikings    58     18  31.0%     6      4
# 30             31    Pittsburgh Steelers    44     17  38.6%     3      1
# 31             32  Washington Commanders    52     17  32.7%     6      4
#
#        4D% RZAtt RZTD  ... Rushing_Yds RushingTDs Rushing_Y/A Rushing_1stD  \
# 0    75.0%    19    8  ...         426          0         3.1           25
# 1    60.0%    13    5  ...         584          2         4.9           30
# 2    42.9%    22    9  ...         757          7         4.2           54
# 3    66.7%    17   12  ...         458          4         3.8           25
# 4    57.1%    13   10  ...         411          2         4.2           19
# 5    75.0%    25   15  ...         641         11         4.4           39
# 6   100.0%    17   10  ...         591          4         4.8           26
# 7    44.4%    14    5  ...         563          2         4.4           29
# 8    60.0%    17    8  ...         552          3           4           29
# 9    90.0%    19   12  ...         600          6         4.8           42
# 10   75.0%    22   14  ...         772          9         4.8           43
# 11   66.7%    12    8  ...         479          3         3.9           32
# 12   61.5%    15   10  ...         640          3         4.8           32
# 13   77.8%    16   14  ...         572          8         3.5           43
# 14   33.3%    17    7  ...         584          2         4.1           34
# 15   66.7%    19   13  ...         672          7         5.4           38
# 16   40.0%    11    7  ...         409          3         3.8           26
# 17   40.0%    15   10  ...         703          6           5           34
# 18   50.0%    20   11  ...         685          6         4.9           37
# 19   77.8%    25   19  ...         674          8         4.4           37
# 20   50.0%    18   13  ...         565          6           4           33
# 21   50.0%    13    6  ...         546          4         4.3           31
# 22   87.5%    19   12  ...         476          6         3.7           32
# 23   62.5%    21   11  ...         561          3         4.6           34
# 24  100.0%    11    8  ...         285          2         3.1           18
# 25   53.8%    13    8  ...         722          4         5.4           41
# 26   85.7%    11    6  ...         581          3         4.4           31
# 27   33.3%    15    8  ...         578          6         5.5           27
# 28   33.3%     9    4  ...         426          2         3.8           26
# 29   66.7%    15   10  ...         534          4         4.5           29
# 30   33.3%    13    9  ...         320          3         3.3           26
# 31   66.7%    14   10  ...         782          7         5.9           38
#
#    Pen_offense Pen_Yds_offense 1stPy_offense Sc%_y TO%_allowed     EXP
# 0           32             268            10  41.5        15.1   26.95
# 1           39             299            11    38          12    8.65
# 2           49             470            17  36.1        13.1    8.46
# 3           35             245            11  45.2         4.8   40.93
# 4           34             241             2  39.5        11.6   23.65
# 5           39             301            14  63.6         6.8   79.78
# 6           41             273             9    36          10   12.64
# 7           31             279             8  31.5        18.5  -10.45
# 8           35             306            16  47.2         3.8   41.03
# 9           42             350             6  51.1         4.3   46.25
# 10          36             287            14  52.8         7.5   69.24
# 11          37             307             8  24.1        13.8  -42.37
# 12          30             248            14    36          14    5.89
# 13          41             392            10  33.9         4.8   18.75
# 14          42             295            16    34         5.7    4.83
# 15          42             359            17    50        11.1   76.07
# 16          34             278             6  37.8         8.9    6.19
# 17          43             411            16  35.7         8.9   29.05
# 18          42             333             9    40        10.9   16.58
# 19          32             227             5  47.4         5.3   68.89
# 20          27             240            12    46          14    45.9
# 21          21             152             6  38.1        11.9    9.16
# 22          42             346             9  40.8        14.3   34.18
# 23          27             229            11  43.4        11.3    44.3
# 24          31             202            14  26.8        19.6  -38.64
# 25          42             352             9  38.5        11.5    0.26
# 26          34             267            13  43.1         9.8    16.2
# 27          31             194             8  45.3        13.2   23.45
# 28          41             331             7  29.8        12.3  -52.41
# 29          44             337             9  35.1          14   -6.73
# 30          19             135            11  38.6         6.8   15.09
# 31          37             271            13  46.9         6.1   41.05
#
# [32 rows x 255 columns]

# %%
merged_nfl_data.to_csv("/Users/stephenmcdevitt/DS-440-Capstone/datasets/mergeddata.csv")

# %%
# datasets = [
#     conversions, conversions_against,
#     drive_averages, drive_averages_against,
#     kick_and_punt_returns_against, kick_and_punt_returns,
#     kicking, passing_against, passing,
#     punting, punting_against, rushing_against,
#     rushing, scoring_defense, scoring_offense,
#     team_advanced_defense, team_defense_statistics, team_offense
# ]

# dataset_names = ["conversions", "conversions_against",
#     "drive_averages", "drive_averages_against",
#     "kick_and_punt_returns_against", "kick_and_punt_returns",
#     "kicking", "passing_against", "passing",
#     "punting", "punting_against", "rushing_against",
#     "rushing", "scoring_defense", "scoring_offense",
#     "team_advanced_defense", "team_defense_statistics", "team_offense"]

# for name, df in zip(dataset_names, datasets):
#     if "Tm" not in df.columns or "G" not in df.columns:
#         print(f"⚠️ {name} is missing one of the merge columns! Columns: {df.columns.tolist()}")




# merged_df = functools.reduce(lambda left, right: pd.merge(left, right, on=["Tm" ,"G"], how="outer"), dfs)
