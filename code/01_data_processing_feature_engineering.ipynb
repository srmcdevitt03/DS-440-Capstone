# %%
# Dictionary with key indicating table name, list index zero is link to the table's site and list index 1 is the HTML ID of the table
master_table_dict = {
    "conversions" : ["https://www.pro-football-reference.com/years/2025/index.htm", "div_team_conversions"],
    "conversions_against" : ["https://www.pro-football-reference.com/years/2025/opp.htm", "div_team_conversions"],
    "drive_averages" : ["https://www.pro-football-reference.com/years/2025/index.htm", "div_drives"],
    "drive_averages_against" : ["https://www.pro-football-reference.com/years/2025/opp.htm", "div_drives"],
    "kick_and_punt_returns" : ["https://www.pro-football-reference.com/years/2025/index.htm", "div_returns"],
    "kick_and_punt_returns_against" : ["https://www.pro-football-reference.com/years/2025/opp.htm", "div_returns"],
    "passing_offense" : ["https://www.pro-football-reference.com/years/2025/index.htm", "div_passing"],
    "passing_defense" : ["https://www.pro-football-reference.com/years/2025/opp.htm", "div_passing"],
    "punting" : ["https://www.pro-football-reference.com/years/2025/index.htm", "div_punting"],
    "punting_against" : ["https://www.pro-football-reference.com/years/2025/opp.htm", "div_punting"],
    "rushing_offense" : ["https://www.pro-football-reference.com/years/2025/index.htm", "div_rushing"],
    "rushing_defense" : ["https://www.pro-football-reference.com/years/2025/opp.htm", "div_rushing"],
    "scoring_offense" : ["https://www.pro-football-reference.com/years/2025/index.htm", "div_team_scoring"],
    "scoring_defense" : ["https://www.pro-football-reference.com/years/2025/opp.htm", "div_team_scoring"],
    "team_advanced_defense" : ["https://www.pro-football-reference.com/years/2025/opp.htm", "div_advanced_defense"],
    "team_defense_statistics" : ["https://www.pro-football-reference.com/years/2025/opp.htm", "div_team_stats"],
    "team_offense" : ["https://www.pro-football-reference.com/years/2025/index.htm", "div_team_stats"]
}

# %% [markdown]
# ## Pull All Data

# %%
import requests
from bs4 import BeautifulSoup, Comment
import pandas as pd
import time
from io import StringIO
import warnings
warnings.filterwarnings("ignore", category=FutureWarning, module="pandas")

headers = {"User-Agent": "Mozilla/5.0"}
dataframes = {}

for key, (url, div_id) in master_table_dict.items():
    print(f"Fetching '{key}' from {url} ...")

    resp = requests.get(url, headers=headers)
    resp.raise_for_status()
    soup = BeautifulSoup(resp.text, "html.parser")

    # first try: div directly in HTML
    div = soup.find("div", id=div_id)

    # second try: div hidden inside HTML comments
    if div is None:
        comments = soup.find_all(string=lambda text: isinstance(text, Comment))
        for c in comments:
            if div_id in c:
                soup_comment = BeautifulSoup(c, "html.parser")
                div = soup_comment.find("div", id=div_id)
                break

    if div is None:
        print(f"⚠️  Skipping '{key}': no div found for {div_id}")
        continue

    table = div.find("table") if div else None
    if table is None:
        print(f"⚠️  Skipping '{key}': no table found inside div {div_id}")
        continue

    try:
        df = pd.read_html(StringIO(str(table)))[0]
        dataframes[key] = df
        print(f"✅ Saved table '{key}' with {df.shape[0]} rows and {df.shape[1]} columns.")
    except Exception as e:
        print(f"❌ Error parsing '{key}': {e}")

    # sleep 10 seconds between requests
    print("⏳ Waiting 10 seconds to respect site guidelines...")
    time.sleep(10)

print("\n✅ Finished fetching all tables.")
# Out:
# Fetching 'conversions' from https://www.pro-football-reference.com/years/2025/index.htm ...
# ✅ Saved table 'conversions' with 33 rows and 12 columns.
# ⏳ Waiting 10 seconds to respect site guidelines...
# Fetching 'conversions_against' from https://www.pro-football-reference.com/years/2025/opp.htm ...
# ✅ Saved table 'conversions_against' with 33 rows and 12 columns.
# ⏳ Waiting 10 seconds to respect site guidelines...
# Fetching 'drive_averages' from https://www.pro-football-reference.com/years/2025/index.htm ...
# ✅ Saved table 'drive_averages' with 33 rows and 12 columns.
# ⏳ Waiting 10 seconds to respect site guidelines...
# Fetching 'drive_averages_against' from https://www.pro-football-reference.com/years/2025/opp.htm ...
# ✅ Saved table 'drive_averages_against' with 33 rows and 12 columns.
# ⏳ Waiting 10 seconds to respect site guidelines...
# Fetching 'kick_and_punt_returns' from https://www.pro-football-reference.com/years/2025/index.htm ...
# ✅ Saved table 'kick_and_punt_returns' with 35 rows and 14 columns.
# ⏳ Waiting 10 seconds to respect site guidelines...
# Fetching 'kick_and_punt_returns_against' from https://www.pro-football-reference.com/years/2025/opp.htm ...
# ✅ Saved table 'kick_and_punt_returns_against' with 35 rows and 11 columns.
# ⏳ Waiting 10 seconds to respect site guidelines...
# Fetching 'passing_offense' from https://www.pro-football-reference.com/years/2025/index.htm ...
# ✅ Saved table 'passing_offense' with 35 rows and 25 columns.
# ⏳ Waiting 10 seconds to respect site guidelines...
# Fetching 'passing_defense' from https://www.pro-football-reference.com/years/2025/opp.htm ...
# ✅ Saved table 'passing_defense' with 35 rows and 25 columns.
# ⏳ Waiting 10 seconds to respect site guidelines...
# Fetching 'punting' from https://www.pro-football-reference.com/years/2025/index.htm ...
# ✅ Saved table 'punting' with 35 rows and 15 columns.
# ⏳ Waiting 10 seconds to respect site guidelines...
# Fetching 'punting_against' from https://www.pro-football-reference.com/years/2025/opp.htm ...
# ✅ Saved table 'punting_against' with 35 rows and 7 columns.
# ⏳ Waiting 10 seconds to respect site guidelines...
# Fetching 'rushing_offense' from https://www.pro-football-reference.com/years/2025/index.htm ...
# ✅ Saved table 'rushing_offense' with 35 rows and 11 columns.
# ⏳ Waiting 10 seconds to respect site guidelines...
# Fetching 'rushing_defense' from https://www.pro-football-reference.com/years/2025/opp.htm ...
# ✅ Saved table 'rushing_defense' with 35 rows and 9 columns.
# ⏳ Waiting 10 seconds to respect site guidelines...
# Fetching 'scoring_offense' from https://www.pro-football-reference.com/years/2025/index.htm ...
# ✅ Saved table 'scoring_offense' with 35 rows and 21 columns.
# ⏳ Waiting 10 seconds to respect site guidelines...
# Fetching 'scoring_defense' from https://www.pro-football-reference.com/years/2025/opp.htm ...
# ✅ Saved table 'scoring_defense' with 35 rows and 21 columns.
# ⏳ Waiting 10 seconds to respect site guidelines...
# Fetching 'team_advanced_defense' from https://www.pro-football-reference.com/years/2025/opp.htm ...
# ✅ Saved table 'team_advanced_defense' with 32 rows and 19 columns.
# ⏳ Waiting 10 seconds to respect site guidelines...
# Fetching 'team_defense_statistics' from https://www.pro-football-reference.com/years/2025/opp.htm ...
# ✅ Saved table 'team_defense_statistics' with 35 rows and 28 columns.
# ⏳ Waiting 10 seconds to respect site guidelines...
# Fetching 'team_offense' from https://www.pro-football-reference.com/years/2025/index.htm ...
# ✅ Saved table 'team_offense' with 35 rows and 28 columns.
# ⏳ Waiting 10 seconds to respect site guidelines...
#
# ✅ Finished fetching all tables.

# %% [markdown]
# ## Engineer `conversions` Tables

# %%
engineered_dfs = {}

# %%
dataframes["conversions"].columns = [
    "Rk_conversions", "Tm", "G", "3DAtt", "3DConv", "3D%", 
    "4DAtt", "4DConv", "4D%", "RZAtt", "RZTD", "RZPct"
]
engineered_dfs["conversions"] = dataframes["conversions"].reset_index(drop=True)

dataframes["conversions_against"].columns = [
    "Rk_conversions_against", "Tm", "G", "3DAtt_against", "3DConv_against", "3D%_against", 
    "4DAtt_against", "4DConv_against", "4D%_against", "RZAtt_against", "RZTD_against", "RZPct_against"
]
engineered_dfs["conversions_against"] = dataframes["conversions_against"].reset_index(drop=True)

# %%
print(dataframes.keys())
# Out:
# dict_keys(['conversions', 'conversions_against', 'drive_averages', 'drive_averages_against', 'kick_and_punt_returns', 'kick_and_punt_returns_against', 'passing_offense', 'passing_defense', 'punting', 'punting_against', 'rushing_offense', 'rushing_defense', 'scoring_offense', 'scoring_defense', 'team_advanced_defense', 'team_defense_statistics', 'team_offense'])

# %% [markdown]
# ## Engineer `drive_averages` Tables

# %%
dataframes["drive_averages"].columns = [
    "Rk_drive_averages", "Tm", "G", "#Dr", "Plays", "Sc%", 
    "TO%", "Avg_plays", "Avg_yards", "Avg_start", "Avg_time", "Avg_pts"
]
engineered_dfs["drive_averages"] = dataframes["drive_averages"].reset_index(drop=True)

dataframes["drive_averages_against"].columns = [
    "Rk_drive_averages_against", "Tm", "G", "#Dr_against", "Plays_against", "Sc%_against", 
    "TO%_against", "Avg_plays_against", "Avg_yards_against", "Avg_start_against", "Avg_time_against", "Avg_pts_against"
]
engineered_dfs["drive_averages_against"] = dataframes["drive_averages_against"].reset_index(drop=True)

# %% [markdown]
# ## Engineer `kick_and_punt_returns` Tables

# %%
dataframes["kick_and_punt_returns"].columns = ["Rk_kick_and_punt_returns", "Tm", "G", "Punt_Returns", 
                                         "Punt_return_yds", "Punt_return_TD", "Punt_return_lng", "Punt_return_Y/R", "Kick_return", 
                                         "Kick_return_yds", "Kick_return_TD", "Kick_return_lng", "Kick_return_Y/Rt", "Kick_return_APYd"]

engineered_dfs["kick_and_punt_returns"] = dataframes["kick_and_punt_returns"].reset_index(drop=True)

dataframes["kick_and_punt_returns_against"].columns = ["Rk_kick_and_punt_returns_against", "Tm", "G", "Punt_Returns_Against", 
                                         "Punt_return_yds_against", "Punt_return_TD_against", "Punt_return_Y/R_against", "Kick_return_against", 
                                         "Kick_return_yds_against", "Kick_return_TD_against", "Kick_return_Y/Rt_against"]

engineered_dfs["kick_and_punt_returns_against"] = dataframes["kick_and_punt_returns_against"].reset_index(drop=True)

# %% [markdown]
# ## Engineer `passing` Tables

# %%
dataframes["passing_offense"].columns = ["Rk_passing", "Tm", "G", 
                   "Cmp", "Passing_Att", "Cmp%", "Passing_yds", 
                   "Passing_tds", "Passing_td%", "Int_thrown", "Int%_thrown", 
                   "Passing_lng", "Y/A_passing", "AY/A_passing", "Y/C_passing", 
                   "Y/G_passing", "rate", "Sk_allowed", "SkYds_allowed", "Sk%_allowed", 
                   "NY/A_passing", "ANY/A_passing", "4QC", "GWD", "EXP_passing"]
engineered_dfs["passing_offense"]=dataframes["passing_offense"]

dataframes["passing_defense"].columns = ["Rk_passing_defense", "Tm", "G", 
                           "Cmp_allowed", "Att_allowed_passing", "Cmp%_allowed", 
                           "Passing_yds_allowed", "Passing_TDs_allowed", 
                           "Passing_TD%_allowed", "Int", "Passes_defended", 
                           "Int%", "Y/A_passing_allowed", "AY/A_passing_allowed", 
                           "Y/C_passing_allowed", "Y/G_passing_allowed", "Rate_allowed", "Sk", 
                           "SkYds", "QBHits", "TFL", "Sk%", "NY/A_passing_allowed", "NY/A_passing_allowed", "EXP_passing_defense"]

engineered_dfs["passing_defense"] = dataframes["passing_defense"]

# %% [markdown]
# ## Engineer `punting` Tables

# %%
dataframes["punting"].columns = ["punting_rk", "Tm", "G", "Pnt", 
                   "Pnt_Yds_total", "Y/P", "RetYds", "Net", 
                   "NY/P", "Lng", "TB", "TB%", "In20", "In20%", "Blk_allowed"]

engineered_dfs["punting"] = dataframes["punting"].reset_index(drop=True)

dataframes["punting_against"].columns = ["Punting_against_rk", "Tm", "G", "Pnt_against", "Pnt_Yds_against", "Y/P_against", "Blk"]

engineered_dfs["punting_against"] = dataframes["punting_against"].reset_index(drop=True)

# %% [markdown]
# ## Engineer `rushing` Tables

# %%
dataframes["rushing_offense"].columns = ["Rk_rushing", "Tm", "G", "Rushing_Att", "Rushing_yds", "Rushing_tds", "Lng_rushing", 
                   "Y/A_rushing", "Y/G_rushing", "Fmb", "EXP_rushing"]

engineered_dfs["rushing_offense"] = dataframes["rushing_offense"]

dataframes["rushing_defense"].columns = ["Rk_rushing_allowed", "Tm", "G", "Rushing_att_allowed", 
                           "Rushing_Yds_allowed", "Rushing_Tds_allowed", "Y/A_rushing_allowed", "Y/G_rushing_allowed", "EXP_rushing_allowed"]

engineered_dfs["rushing_defense"] = dataframes["rushing_defense"]

# %% [markdown]
# ## Engineer `scoring` Tables

# %%
dataframes["scoring_offense"].columns = ["Rk_scoring_offense", "Tm", "G", "RshTd", 
                           "RecTd", "PR_TD", "KR_TD", "FblTD", "IntTD", 
                           "OthTD", "AllTD", "2PM", "2PA", "D2P", "XPM", "XPA", 
                           "FGM", "FGA", "Sfty", "Pts", "Pts/G"]

engineered_dfs["scoring_offense"] = dataframes["scoring_offense"]

dataframes["scoring_defense"].columns = ["Rk_scoring_defense", "Tm", "G", "RshTD_allowed", 
                           "RecTD_allowed", "PR_TD_allowed", "KR_TD_allowed", "FblTD_allowed", 
                           "IntTD_allowed", "OthTD_allowed", "AllTD_allowed", "2PM_allowed", "2PA_allowed", 
                           "D2P_allowed", "XPM_allowed", "XPA_allowed", "FGM_allowed", "FGA_allowed", 
                           "Sfty_allowed", "Pts_allowed", "Pts/G_allowed"]

engineered_dfs["scoring_defense"] = dataframes["scoring_defense"]

# %% [markdown]
# ## Engineer `team_advanced_defense` Table

# %%
dataframes["team_advanced_defense"].columns = ["Tm", "G", "Att_allowed_passing", 
                                 "Cmp_allowed_passing", "Yds_allowed_passing", 
                                 "TD_allowed_passing", "DADOT", "Air_yards_Cmp", "YAC_allowed", 
                                 "Bltz", "Bltz%", "Hrry", "Hrry%", "QBKD", "QBKD%", "Sk", "Prss", "Prss%", "MTkl"]

engineered_dfs["team_advanced_defense"] = dataframes["team_advanced_defense"]

# %% [markdown]
# ## Engineer `team_stats` Tables

# %%
dataframes["team_defense_statistics"].columns = ["Rk_team_defense", "Tm", "G", "PA", 
                                   "Yds_allowed", "Ply_allowed", "Y/P_allowed", 
                                   "Takeaways", "FL_forced", "1stD_allowed", "Cmp_allowed_passing", 
                                   "Att_allowed_passing", "Yds_allowed_passing", "TDs_allowed_passing", 
                                   "Int", "NY/A_allowed_passing", "1stD_allowed_passing", "Rushing_att_allowed", 
                                   "Rushing_Yds_allowed", "Rushing_Tds_allowed", "Y/A_rushing_allowed", "1stD_allowed_rushing", 
                                   "Pen_defense", "Pen_yds_defense", "1stPy_defense", "Sc%_allowed", "TO%", "EXP_allowed"]

engineered_dfs["team_defense"] = dataframes["team_defense_statistics"].reset_index(drop=True)

dataframes["team_offense"].columns = ["Rk_team_offense", "Tm", "G", "PF", "Yds", "Ply", 
                        "Y/P", "TO_allowed", "FL_allowed", "1stD", "Cmp_passing", 
                        "Att_passing", "Passing_Yds", "Passing_TDs", "Int_allowed", "NY/A_passing", 
                        "1stD_passing", "Rushing_Att", "Rushing_Yds", "RushingTDs", "Rushing_Y/A", 
                        "Rushing_1stD", "Pen_offense","Pen_Yds_offense", "1stPy_offense", "Sc%", "TO%_allowed", "EXP"]

engineered_dfs["team_offense"] = dataframes["team_offense"].reset_index(drop=True)

# %% [markdown]
# ## Final Join of All Tables

# %%
import functools
dfs = [
engineered_dfs["conversions"], engineered_dfs["conversions_against"], engineered_dfs["drive_averages"],
engineered_dfs["drive_averages_against"], engineered_dfs["kick_and_punt_returns"], engineered_dfs["kick_and_punt_returns_against"], 
engineered_dfs["passing_offense"], engineered_dfs["passing_defense"], engineered_dfs["punting"], engineered_dfs["punting_against"],
engineered_dfs["rushing_offense"], engineered_dfs["rushing_defense"], engineered_dfs["scoring_offense"], engineered_dfs["scoring_defense"], 
engineered_dfs["team_advanced_defense"], engineered_dfs["team_defense"], engineered_dfs["team_offense"]
]

# for i, df in enumerate(dfs):
#     print(f"Dataset {i+1} G dtype:", df["G"].dtype)

# for df in dfs:
#     df["G"] = df["G"].astype(str)

for df in dfs:
    if "G" in df.columns:
        df.drop(columns=["G"], inplace=True)

merged_nfl_data = functools.reduce(
    lambda left, right: pd.merge(left, right, on="Tm", how="outer"),
    dfs
)

merged_nfl_data
# Out:
#     Rk_conversions                     Tm  3DAtt  3DConv    3D%  4DAtt  \
# 0              3.0      Arizona Cardinals   96.0    43.0  44.8%    7.0
# 1             16.0        Atlanta Falcons   78.0    33.0  42.3%   11.0
# 2              NaN               Avg Team    NaN     NaN    NaN    NaN
# 3              NaN               Avg Tm/G    NaN     NaN    NaN    NaN
# 4             26.0       Baltimore Ravens   69.0    28.0  40.6%   12.0
# 5             27.0          Buffalo Bills   68.0    28.0  41.2%    5.0
# 6             12.0      Carolina Panthers   91.0    34.0  37.4%   18.0
# 7             21.0          Chicago Bears   77.0    31.0  40.3%    7.0
# 8             10.0     Cincinnati Bengals   90.0    35.0  38.9%    4.0
# 9              8.0       Cleveland Browns  104.0    36.0  34.6%   16.0
# 10             6.0         Dallas Cowboys   84.0    37.0  44.0%    8.0
# 11            15.0         Denver Broncos   95.0    34.0  35.8%    8.0
# 12            19.0          Detroit Lions   85.0    32.0  37.6%   13.0
# 13             7.0      Green Bay Packers   75.0    37.0  49.3%    7.0
# 14            32.0         Houston Texans   75.0    23.0  30.7%   11.0
# 15             9.0     Indianapolis Colts   77.0    36.0  46.8%   11.0
# 16            20.0   Jacksonville Jaguars   94.0    31.0  33.0%   15.0
# 17             4.0     Kansas City Chiefs   90.0    40.0  44.4%   15.0
# 18            17.0      Las Vegas Raiders   87.0    33.0  37.9%   11.0
# 19             NaN           League Total    NaN     NaN    NaN    NaN
# 20             2.0   Los Angeles Chargers  100.0    46.0  46.0%   10.0
# 21            25.0       Los Angeles Rams   77.0    29.0  37.7%   12.0
# 22            14.0         Miami Dolphins   84.0    34.0  40.5%   11.0
# 23            31.0      Minnesota Vikings   73.0    25.0  34.2%    7.0
# 24            13.0   New England Patriots   82.0    34.0  41.5%   12.0
# 25            18.0     New Orleans Saints   87.0    32.0  36.8%   11.0
# 26             5.0        New York Giants   96.0    38.0  39.6%   16.0
# 27            22.0          New York Jets   91.0    30.0  33.0%   16.0
# 28            23.0    Philadelphia Eagles   85.0    29.0  34.1%   12.0
# 29            24.0    Pittsburgh Steelers   67.0    29.0  43.3%    3.0
# 30             1.0    San Francisco 49ers  101.0    48.0  47.5%   10.0
# 31            29.0       Seattle Seahawks   81.0    27.0  33.3%    6.0
# 32            11.0   Tampa Bay Buccaneers   89.0    34.0  38.2%   10.0
# 33            30.0       Tennessee Titans   92.0    26.0  28.3%   10.0
# 34            28.0  Washington Commanders   76.0    27.0  35.5%    9.0
#
#     4DConv     4D%  RZAtt  RZTD  ... Rushing_Yds  RushingTDs  Rushing_Y/A  \
# 0      4.0   57.1%   27.0  15.0  ...       773.0         5.0          4.4
# 1      4.0   36.4%   18.0   8.0  ...       818.0         6.0          4.6
# 2      NaN     NaN    NaN   NaN  ...       759.3         5.9          4.3
# 3      NaN     NaN    NaN   NaN  ...       112.5         0.9          4.3
# 4      4.0   33.3%   18.0   8.0  ...       757.0         6.0          5.3
# 5      3.0   60.0%   25.0  16.0  ...       906.0         9.0          4.9
# 6     12.0   66.7%   22.0  13.0  ...       981.0         3.0          4.7
# 7      3.0   42.9%   20.0  10.0  ...       776.0         6.0          4.4
# 8      4.0  100.0%   18.0  12.0  ...       482.0         2.0          3.7
# 9     10.0   62.5%   18.0  10.0  ...       648.0         6.0          3.7
# 10     6.0   75.0%   27.0  18.0  ...       855.0         8.0          4.9
# 11     4.0   50.0%   22.0  15.0  ...       923.0         8.0          4.8
# 12     8.0   61.5%   29.0  21.0  ...       936.0        10.0          4.5
# 13     5.0   71.4%   25.0  18.0  ...       705.0         8.0          4.0
# 14     7.0   63.6%   14.0   7.0  ...       637.0         3.0          4.2
# 15     9.0   81.8%   34.0  23.0  ...       911.0        16.0          4.6
# 16     8.0   53.3%   22.0  11.0  ...       838.0         6.0          4.7
# 17    12.0   80.0%   30.0  20.0  ...       864.0         8.0          4.4
# 18     5.0   45.5%   18.0   7.0  ...       656.0         3.0          3.9
# 19     NaN     NaN    NaN   NaN  ...     24297.0       189.0          4.3
# 20     7.0   70.0%   24.0  10.0  ...       778.0         2.0          4.9
# 21     8.0   66.7%   30.0  17.0  ...       724.0         4.0          4.1
# 22     6.0   54.5%   18.0  12.0  ...       647.0         4.0          4.6
# 23     5.0   71.4%   21.0  11.0  ...       623.0         5.0          4.4
# 24    10.0   83.3%   23.0  14.0  ...       724.0         7.0          3.7
# 25     3.0   27.3%   20.0   9.0  ...       701.0         3.0          3.8
# 26     8.0   50.0%   24.0  11.0  ...       876.0         9.0          4.1
# 27     8.0   50.0%   14.0   8.0  ...       895.0         4.0          4.9
# 28     9.0   75.0%   17.0  14.0  ...       617.0         8.0          3.3
# 29     1.0   33.3%   18.0  13.0  ...       567.0         3.0          3.9
# 30     6.0   60.0%   23.0  11.0  ...       667.0         3.0          3.3
# 31     4.0   66.7%   25.0  17.0  ...       743.0         8.0          3.7
# 32     5.0   50.0%   20.0  10.0  ...       697.0         5.0          4.0
# 33     4.0   40.0%   11.0   5.0  ...       530.0         2.0          3.8
# 34     5.0   55.6%   18.0  14.0  ...      1042.0         9.0          5.4
#
#     Rushing_1stD Pen_offense  Pen_Yds_offense  1stPy_offense Sc%_y  \
# 0           38.0        54.0            393.0           15.0  40.6
# 1           43.0        33.0            230.0           12.0  34.9
# 2           43.7        48.1            384.3           14.3  39.6
# 3            6.5         7.1             56.9            2.1  39.6
# 4           38.0        38.0            274.0           10.0  40.3
# 5           50.0        44.0            351.0           16.0  46.9
# 6           53.0        42.0            350.0           16.0  38.6
# 7           47.0        53.0            454.0            7.0  43.3
# 8           31.0        38.0            254.0           20.0  33.3
# 9           43.0        48.0            388.0           16.0  26.9
# 10          46.0        58.0            475.0           22.0  52.0
# 11          45.0        61.0            575.0           18.0  35.0
# 12          48.0        42.0            315.0            7.0  43.6
# 13          42.0        50.0            379.0           16.0  47.5
# 14          32.0        44.0            372.0           17.0  38.5
# 15          59.0        47.0            383.0           16.0  61.9
# 16          45.0        65.0            528.0           13.0  32.1
# 17          62.0        47.0            388.0           10.0  52.3
# 18          33.0        45.0            364.0           12.0  28.0
# 19        1398.0      1539.0          12297.0          459.0  39.6
# 20          41.0        52.0            379.0           14.0  44.1
# 21          42.0        38.0            314.0           20.0  41.3
# 22          29.0        49.0            389.0            6.0  36.9
# 23          36.0        47.0            367.0           10.0  39.4
# 24          46.0        58.0            447.0           11.0  41.8
# 25          44.0        55.0            392.0           23.0  34.2
# 26          61.0        57.0            506.0           24.0  37.0
# 27          50.0        49.0            393.0           10.0  33.3
# 28          47.0        49.0            456.0           10.0  33.8
# 29          40.0        36.0            253.0           12.0  42.9
# 30          43.0        44.0            358.0           12.0  43.1
# 31          41.0        46.0            389.0           17.0  41.6
# 32          40.0        46.0            372.0           19.0  41.6
# 33          30.0        51.0            380.0            9.0  28.6
# 34          53.0        53.0            429.0           19.0  40.8
#
#     TO%_allowed     EXP
# 0          10.1   29.75
# 1           9.5   17.80
# 2          10.4   25.50
# 3          10.4     NaN
# 4          16.1    4.43
# 5           9.4   65.09
# 6          11.4   15.95
# 7           7.5   18.74
# 8          14.7  -11.29
# 9          10.3  -47.15
# 10          8.0  106.40
# 11          7.5   30.54
# 12          6.4   72.72
# 13          4.9   66.63
# 14          9.2   -4.58
# 15          6.3  121.34
# 16          7.7    8.73
# 17          3.1   85.26
# 18         16.0  -33.65
# 19         10.4     NaN
# 20         13.2   30.89
# 21          9.3   60.67
# 22         16.9    4.13
# 23         15.2   -5.74
# 24         10.4   59.45
# 25         11.0   -1.29
# 26         12.3   24.75
# 27         10.7  -36.91
# 28          4.2   31.30
# 29          7.9   38.52
# 30         15.3   27.21
# 31         14.3   34.55
# 32          5.2   37.93
# 33         15.6  -74.30
# 34         11.3   36.99
#
# [35 rows x 249 columns]

# %%
merged_nfl_data = merged_nfl_data[
    ~merged_nfl_data["Tm"].isin(["League Total", "Avg Team", "Avg Tm/G"])
]

#merged_nfl_data

# %%
merged_nfl_data.columns[merged_nfl_data.columns.duplicated()]
# Out:
# Index(['NY/A_passing_allowed'], dtype='object')

# %%
merged_nfl_data.columns.value_counts()
# Out:
# NY/A_passing_allowed     2
# Rk_conversions           1
# 2PA_allowed              1
# Pts                      1
# Pts/G                    1
#                         ..
# Att_allowed_passing_x    1
# Cmp%_allowed             1
# Passing_yds_allowed      1
# Passing_TDs_allowed      1
# EXP                      1
# Name: count, Length: 248, dtype: int64

# %%
merged_nfl_data = merged_nfl_data.loc[:, ~merged_nfl_data.columns.duplicated()]

# %%
engineered_dfs["master_nfl_data"] = merged_nfl_data

# %%
import base64
import requests

# Replace these with your own values
token = "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"
username = "srmcdevitt03"
repo = "DS-440-Capstone"

# Helper function to upload to GitHub
def upload_to_github(filename, content, message):
    content_encoded = content.to_csv(index=False)
    url = f"https://api.github.com/repos/{username}/{repo}/contents/datasets/{filename}"
    data = {
        "message": message,
        "content": base64.b64encode(content_encoded.encode()).decode()
    }
    headers = {"Authorization": f"token {token}"}
    response = requests.put(url, json=data, headers=headers)
    print(response.json())

# %%
print(engineered_dfs.keys())
# Out:
# dict_keys(['conversions', 'conversions_against', 'drive_averages', 'drive_averages_against', 'kick_and_punt_returns', 'kick_and_punt_returns_against', 'passing_offense', 'passing_defense', 'punting', 'punting_against', 'rushing_offense', 'rushing_defense', 'scoring_offense', 'scoring_defense', 'team_advanced_defense', 'team_defense', 'team_offense', 'master_nfl_data'])

# %%
for key in engineered_dfs.keys():
    upload_to_github(f"{key}.csv", engineered_dfs[key], f"Updating {key} table following NFL Week 7")
# Out:
# {'content': {'name': 'conversions.csv', 'path': 'datasets/conversions.csv', 'sha': 'cb3f839dd61ee220062b0820154cac5eaf864b7d', 'size': 2302, 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/conversions.csv?ref=main', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/conversions.csv', 'git_url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/cb3f839dd61ee220062b0820154cac5eaf864b7d', 'download_url': 'https://raw.githubusercontent.com/srmcdevitt03/DS-440-Capstone/main/datasets/conversions.csv', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/conversions.csv?ref=main', 'git': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/cb3f839dd61ee220062b0820154cac5eaf864b7d', 'html': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/conversions.csv'}}, 'commit': {'sha': '2bf42adbc93890027e76a67ed75fff88041e21bc', 'node_id': 'C_kwDOP-D23doAKDJiZjQyYWRiYzkzODkwMDI3ZTc2YTY3ZWQ3NWZmZjg4MDQxZTIxYmM', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/2bf42adbc93890027e76a67ed75fff88041e21bc', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/2bf42adbc93890027e76a67ed75fff88041e21bc', 'author': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:16Z'}, 'committer': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:16Z'}, 'tree': {'sha': 'f98f20b9de6cccc39d3b11a712a0544f054194ab', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/trees/f98f20b9de6cccc39d3b11a712a0544f054194ab'}, 'message': 'Updating conversions table following NFL Week 7', 'parents': [{'sha': 'e39315071b798adbef4344aca52457bbe1e6b5b9', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/e39315071b798adbef4344aca52457bbe1e6b5b9', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/e39315071b798adbef4344aca52457bbe1e6b5b9'}], 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}}
# {'content': {'name': 'conversions_against.csv', 'path': 'datasets/conversions_against.csv', 'sha': '3e5dc1ab2f7906bf4b6eac8571f642b8fab85eb2', 'size': 2377, 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/conversions_against.csv?ref=main', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/conversions_against.csv', 'git_url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/3e5dc1ab2f7906bf4b6eac8571f642b8fab85eb2', 'download_url': 'https://raw.githubusercontent.com/srmcdevitt03/DS-440-Capstone/main/datasets/conversions_against.csv', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/conversions_against.csv?ref=main', 'git': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/3e5dc1ab2f7906bf4b6eac8571f642b8fab85eb2', 'html': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/conversions_against.csv'}}, 'commit': {'sha': '8e9c1bacaf7079d44db1cc63b6be0f2aff9b0776', 'node_id': 'C_kwDOP-D23doAKDhlOWMxYmFjYWY3MDc5ZDQ0ZGIxY2M2M2I2YmUwZjJhZmY5YjA3NzY', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/8e9c1bacaf7079d44db1cc63b6be0f2aff9b0776', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/8e9c1bacaf7079d44db1cc63b6be0f2aff9b0776', 'author': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:17Z'}, 'committer': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:17Z'}, 'tree': {'sha': 'ee0ae896e65d0f8c1db1d90813d3f60dfbd867f9', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/trees/ee0ae896e65d0f8c1db1d90813d3f60dfbd867f9'}, 'message': 'Updating conversions_against table following NFL Week 7', 'parents': [{'sha': '2bf42adbc93890027e76a67ed75fff88041e21bc', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/2bf42adbc93890027e76a67ed75fff88041e21bc', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/2bf42adbc93890027e76a67ed75fff88041e21bc'}], 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}}
# {'content': {'name': 'drive_averages.csv', 'path': 'datasets/drive_averages.csv', 'sha': '10a58bbc6752ed74cf4c73ec993a7738ebbac6b3', 'size': 2287, 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/drive_averages.csv?ref=main', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/drive_averages.csv', 'git_url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/10a58bbc6752ed74cf4c73ec993a7738ebbac6b3', 'download_url': 'https://raw.githubusercontent.com/srmcdevitt03/DS-440-Capstone/main/datasets/drive_averages.csv', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/drive_averages.csv?ref=main', 'git': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/10a58bbc6752ed74cf4c73ec993a7738ebbac6b3', 'html': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/drive_averages.csv'}}, 'commit': {'sha': 'bcccd0990a0f60d4a724cea8d189dffad3af92fb', 'node_id': 'C_kwDOP-D23doAKGJjY2NkMDk5MGEwZjYwZDRhNzI0Y2VhOGQxODlkZmZhZDNhZjkyZmI', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/bcccd0990a0f60d4a724cea8d189dffad3af92fb', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/bcccd0990a0f60d4a724cea8d189dffad3af92fb', 'author': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:18Z'}, 'committer': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:18Z'}, 'tree': {'sha': '9b9c8a0887bd2542bf3b0d3457596ca9cdd6b9c0', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/trees/9b9c8a0887bd2542bf3b0d3457596ca9cdd6b9c0'}, 'message': 'Updating drive_averages table following NFL Week 7', 'parents': [{'sha': '8e9c1bacaf7079d44db1cc63b6be0f2aff9b0776', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/8e9c1bacaf7079d44db1cc63b6be0f2aff9b0776', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/8e9c1bacaf7079d44db1cc63b6be0f2aff9b0776'}], 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}}
# {'content': {'name': 'drive_averages_against.csv', 'path': 'datasets/drive_averages_against.csv', 'sha': 'b94e334df0ed23a37ef0fd49bc52851039ddf677', 'size': 2366, 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/drive_averages_against.csv?ref=main', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/drive_averages_against.csv', 'git_url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/b94e334df0ed23a37ef0fd49bc52851039ddf677', 'download_url': 'https://raw.githubusercontent.com/srmcdevitt03/DS-440-Capstone/main/datasets/drive_averages_against.csv', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/drive_averages_against.csv?ref=main', 'git': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/b94e334df0ed23a37ef0fd49bc52851039ddf677', 'html': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/drive_averages_against.csv'}}, 'commit': {'sha': '83145965e9425ca8c8f52e4312b3f320399fdb8d', 'node_id': 'C_kwDOP-D23doAKDgzMTQ1OTY1ZTk0MjVjYThjOGY1MmU0MzEyYjNmMzIwMzk5ZmRiOGQ', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/83145965e9425ca8c8f52e4312b3f320399fdb8d', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/83145965e9425ca8c8f52e4312b3f320399fdb8d', 'author': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:18Z'}, 'committer': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:18Z'}, 'tree': {'sha': '2d731e41c148d4008fb9c2e646c63c5c1d6b1150', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/trees/2d731e41c148d4008fb9c2e646c63c5c1d6b1150'}, 'message': 'Updating drive_averages_against table following NFL Week 7', 'parents': [{'sha': 'bcccd0990a0f60d4a724cea8d189dffad3af92fb', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/bcccd0990a0f60d4a724cea8d189dffad3af92fb', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/bcccd0990a0f60d4a724cea8d189dffad3af92fb'}], 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}}
# {'content': {'name': 'kick_and_punt_returns.csv', 'path': 'datasets/kick_and_punt_returns.csv', 'sha': '8e9a2da172e4c70e2fe70c98209a8ee46d2d1ea9', 'size': 2901, 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/kick_and_punt_returns.csv?ref=main', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/kick_and_punt_returns.csv', 'git_url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/8e9a2da172e4c70e2fe70c98209a8ee46d2d1ea9', 'download_url': 'https://raw.githubusercontent.com/srmcdevitt03/DS-440-Capstone/main/datasets/kick_and_punt_returns.csv', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/kick_and_punt_returns.csv?ref=main', 'git': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/8e9a2da172e4c70e2fe70c98209a8ee46d2d1ea9', 'html': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/kick_and_punt_returns.csv'}}, 'commit': {'sha': '91a23f16d944e18d15daf2a31d2ce6e771bab3fa', 'node_id': 'C_kwDOP-D23doAKDkxYTIzZjE2ZDk0NGUxOGQxNWRhZjJhMzFkMmNlNmU3NzFiYWIzZmE', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/91a23f16d944e18d15daf2a31d2ce6e771bab3fa', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/91a23f16d944e18d15daf2a31d2ce6e771bab3fa', 'author': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:19Z'}, 'committer': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:19Z'}, 'tree': {'sha': '5d1cbb984b5f41c9482fe73bf63eb9ce9755f36d', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/trees/5d1cbb984b5f41c9482fe73bf63eb9ce9755f36d'}, 'message': 'Updating kick_and_punt_returns table following NFL Week 7', 'parents': [{'sha': '83145965e9425ca8c8f52e4312b3f320399fdb8d', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/83145965e9425ca8c8f52e4312b3f320399fdb8d', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/83145965e9425ca8c8f52e4312b3f320399fdb8d'}], 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}}
# {'content': {'name': 'kick_and_punt_returns_against.csv', 'path': 'datasets/kick_and_punt_returns_against.csv', 'sha': 'e97836f2380e86e69d787fcad62fcf9ccf366d41', 'size': 2335, 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/kick_and_punt_returns_against.csv?ref=main', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/kick_and_punt_returns_against.csv', 'git_url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/e97836f2380e86e69d787fcad62fcf9ccf366d41', 'download_url': 'https://raw.githubusercontent.com/srmcdevitt03/DS-440-Capstone/main/datasets/kick_and_punt_returns_against.csv', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/kick_and_punt_returns_against.csv?ref=main', 'git': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/e97836f2380e86e69d787fcad62fcf9ccf366d41', 'html': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/kick_and_punt_returns_against.csv'}}, 'commit': {'sha': '1728ce38b990383c0585cff64e3009baa95e1125', 'node_id': 'C_kwDOP-D23doAKDE3MjhjZTM4Yjk5MDM4M2MwNTg1Y2ZmNjRlMzAwOWJhYTk1ZTExMjU', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/1728ce38b990383c0585cff64e3009baa95e1125', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/1728ce38b990383c0585cff64e3009baa95e1125', 'author': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:19Z'}, 'committer': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:19Z'}, 'tree': {'sha': '8b4f5781e1f7771db98d500c0051b87be3b0a31b', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/trees/8b4f5781e1f7771db98d500c0051b87be3b0a31b'}, 'message': 'Updating kick_and_punt_returns_against table following NFL Week 7', 'parents': [{'sha': '91a23f16d944e18d15daf2a31d2ce6e771bab3fa', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/91a23f16d944e18d15daf2a31d2ce6e771bab3fa', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/91a23f16d944e18d15daf2a31d2ce6e771bab3fa'}], 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}}
# {'content': {'name': 'passing_offense.csv', 'path': 'datasets/passing_offense.csv', 'sha': '425e8aafd66ccab83436d83b51497fd5655dd9f8', 'size': 4632, 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/passing_offense.csv?ref=main', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/passing_offense.csv', 'git_url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/425e8aafd66ccab83436d83b51497fd5655dd9f8', 'download_url': 'https://raw.githubusercontent.com/srmcdevitt03/DS-440-Capstone/main/datasets/passing_offense.csv', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/passing_offense.csv?ref=main', 'git': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/425e8aafd66ccab83436d83b51497fd5655dd9f8', 'html': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/passing_offense.csv'}}, 'commit': {'sha': 'd0fd18d9ccc98a3f5fced664dfa338223098a24c', 'node_id': 'C_kwDOP-D23doAKGQwZmQxOGQ5Y2NjOThhM2Y1ZmNlZDY2NGRmYTMzODIyMzA5OGEyNGM', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/d0fd18d9ccc98a3f5fced664dfa338223098a24c', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/d0fd18d9ccc98a3f5fced664dfa338223098a24c', 'author': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:20Z'}, 'committer': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:20Z'}, 'tree': {'sha': 'c533fa14e4ece347fd24219d3377f90311ae1830', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/trees/c533fa14e4ece347fd24219d3377f90311ae1830'}, 'message': 'Updating passing_offense table following NFL Week 7', 'parents': [{'sha': '1728ce38b990383c0585cff64e3009baa95e1125', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/1728ce38b990383c0585cff64e3009baa95e1125', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/1728ce38b990383c0585cff64e3009baa95e1125'}], 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}}
# {'content': {'name': 'passing_defense.csv', 'path': 'datasets/passing_defense.csv', 'sha': 'a745c752bbfa99ecc9afe594cba6cba5d7c38d02', 'size': 4877, 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/passing_defense.csv?ref=main', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/passing_defense.csv', 'git_url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/a745c752bbfa99ecc9afe594cba6cba5d7c38d02', 'download_url': 'https://raw.githubusercontent.com/srmcdevitt03/DS-440-Capstone/main/datasets/passing_defense.csv', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/passing_defense.csv?ref=main', 'git': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/a745c752bbfa99ecc9afe594cba6cba5d7c38d02', 'html': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/passing_defense.csv'}}, 'commit': {'sha': '5162805636abefe238b973f3f42cfb9eb83231a2', 'node_id': 'C_kwDOP-D23doAKDUxNjI4MDU2MzZhYmVmZTIzOGI5NzNmM2Y0MmNmYjllYjgzMjMxYTI', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/5162805636abefe238b973f3f42cfb9eb83231a2', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/5162805636abefe238b973f3f42cfb9eb83231a2', 'author': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:20Z'}, 'committer': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:20Z'}, 'tree': {'sha': '75d59c6635d2840206b83f9c6bfd2e9d42b34908', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/trees/75d59c6635d2840206b83f9c6bfd2e9d42b34908'}, 'message': 'Updating passing_defense table following NFL Week 7', 'parents': [{'sha': 'd0fd18d9ccc98a3f5fced664dfa338223098a24c', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/d0fd18d9ccc98a3f5fced664dfa338223098a24c', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/d0fd18d9ccc98a3f5fced664dfa338223098a24c'}], 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}}
# {'content': {'name': 'punting.csv', 'path': 'datasets/punting.csv', 'sha': '6cbf44c56261478585c690f201b335a7f8e2b622', 'size': 3029, 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/punting.csv?ref=main', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/punting.csv', 'git_url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/6cbf44c56261478585c690f201b335a7f8e2b622', 'download_url': 'https://raw.githubusercontent.com/srmcdevitt03/DS-440-Capstone/main/datasets/punting.csv', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/punting.csv?ref=main', 'git': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/6cbf44c56261478585c690f201b335a7f8e2b622', 'html': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/punting.csv'}}, 'commit': {'sha': 'd5731c25b58082d5072e3adee24bc38f53f38679', 'node_id': 'C_kwDOP-D23doAKGQ1NzMxYzI1YjU4MDgyZDUwNzJlM2FkZWUyNGJjMzhmNTNmMzg2Nzk', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/d5731c25b58082d5072e3adee24bc38f53f38679', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/d5731c25b58082d5072e3adee24bc38f53f38679', 'author': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:21Z'}, 'committer': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:21Z'}, 'tree': {'sha': '79ae782114e094e5d52cc4310fa588ac46aa9db3', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/trees/79ae782114e094e5d52cc4310fa588ac46aa9db3'}, 'message': 'Updating punting table following NFL Week 7', 'parents': [{'sha': '5162805636abefe238b973f3f42cfb9eb83231a2', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/5162805636abefe238b973f3f42cfb9eb83231a2', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/5162805636abefe238b973f3f42cfb9eb83231a2'}], 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}}
# {'content': {'name': 'punting_against.csv', 'path': 'datasets/punting_against.csv', 'sha': 'fb0250acbef4a626ebdd83019f43d9ec0a6f997d', 'size': 1543, 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/punting_against.csv?ref=main', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/punting_against.csv', 'git_url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/fb0250acbef4a626ebdd83019f43d9ec0a6f997d', 'download_url': 'https://raw.githubusercontent.com/srmcdevitt03/DS-440-Capstone/main/datasets/punting_against.csv', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/punting_against.csv?ref=main', 'git': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/fb0250acbef4a626ebdd83019f43d9ec0a6f997d', 'html': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/punting_against.csv'}}, 'commit': {'sha': '8672cf66e4cc914cdc35f8c0de912e7660e7d47b', 'node_id': 'C_kwDOP-D23doAKDg2NzJjZjY2ZTRjYzkxNGNkYzM1ZjhjMGRlOTEyZTc2NjBlN2Q0N2I', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/8672cf66e4cc914cdc35f8c0de912e7660e7d47b', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/8672cf66e4cc914cdc35f8c0de912e7660e7d47b', 'author': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:22Z'}, 'committer': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:22Z'}, 'tree': {'sha': '47c4a192077b470af8ad5b9df663978578362ea9', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/trees/47c4a192077b470af8ad5b9df663978578362ea9'}, 'message': 'Updating punting_against table following NFL Week 7', 'parents': [{'sha': 'd5731c25b58082d5072e3adee24bc38f53f38679', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/d5731c25b58082d5072e3adee24bc38f53f38679', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/d5731c25b58082d5072e3adee24bc38f53f38679'}], 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}}
# {'content': {'name': 'rushing_offense.csv', 'path': 'datasets/rushing_offense.csv', 'sha': 'da0336241868b345fe098620fb1fff27d8d931a8', 'size': 2270, 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/rushing_offense.csv?ref=main', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/rushing_offense.csv', 'git_url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/da0336241868b345fe098620fb1fff27d8d931a8', 'download_url': 'https://raw.githubusercontent.com/srmcdevitt03/DS-440-Capstone/main/datasets/rushing_offense.csv', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/rushing_offense.csv?ref=main', 'git': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/da0336241868b345fe098620fb1fff27d8d931a8', 'html': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/rushing_offense.csv'}}, 'commit': {'sha': 'fffb924a1f812ae4d632ef7250bb8a013ed163e4', 'node_id': 'C_kwDOP-D23doAKGZmZmI5MjRhMWY4MTJhZTRkNjMyZWY3MjUwYmI4YTAxM2VkMTYzZTQ', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/fffb924a1f812ae4d632ef7250bb8a013ed163e4', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/fffb924a1f812ae4d632ef7250bb8a013ed163e4', 'author': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:22Z'}, 'committer': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:22Z'}, 'tree': {'sha': '3743040af4c8633e7167d65dbbb005a2eb986456', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/trees/3743040af4c8633e7167d65dbbb005a2eb986456'}, 'message': 'Updating rushing_offense table following NFL Week 7', 'parents': [{'sha': '8672cf66e4cc914cdc35f8c0de912e7660e7d47b', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/8672cf66e4cc914cdc35f8c0de912e7660e7d47b', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/8672cf66e4cc914cdc35f8c0de912e7660e7d47b'}], 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}}
# {'content': {'name': 'rushing_defense.csv', 'path': 'datasets/rushing_defense.csv', 'sha': 'e082af34960df2c2713112f6551be2c76f100013', 'size': 1994, 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/rushing_defense.csv?ref=main', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/rushing_defense.csv', 'git_url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/e082af34960df2c2713112f6551be2c76f100013', 'download_url': 'https://raw.githubusercontent.com/srmcdevitt03/DS-440-Capstone/main/datasets/rushing_defense.csv', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/rushing_defense.csv?ref=main', 'git': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/e082af34960df2c2713112f6551be2c76f100013', 'html': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/rushing_defense.csv'}}, 'commit': {'sha': 'a230c7fd5f1edf5fe85a108d4208b932a1e60cf2', 'node_id': 'C_kwDOP-D23doAKGEyMzBjN2ZkNWYxZWRmNWZlODVhMTA4ZDQyMDhiOTMyYTFlNjBjZjI', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/a230c7fd5f1edf5fe85a108d4208b932a1e60cf2', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/a230c7fd5f1edf5fe85a108d4208b932a1e60cf2', 'author': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:23Z'}, 'committer': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:23Z'}, 'tree': {'sha': '856bc99a46c3487e9dc71f53d631225765d1065f', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/trees/856bc99a46c3487e9dc71f53d631225765d1065f'}, 'message': 'Updating rushing_defense table following NFL Week 7', 'parents': [{'sha': 'fffb924a1f812ae4d632ef7250bb8a013ed163e4', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/fffb924a1f812ae4d632ef7250bb8a013ed163e4', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/fffb924a1f812ae4d632ef7250bb8a013ed163e4'}], 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}}
# {'content': {'name': 'scoring_offense.csv', 'path': 'datasets/scoring_offense.csv', 'sha': 'ee17ba1e827c3f8d19a4d9a6930034c16849fcfe', 'size': 3054, 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/scoring_offense.csv?ref=main', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/scoring_offense.csv', 'git_url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/ee17ba1e827c3f8d19a4d9a6930034c16849fcfe', 'download_url': 'https://raw.githubusercontent.com/srmcdevitt03/DS-440-Capstone/main/datasets/scoring_offense.csv', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/scoring_offense.csv?ref=main', 'git': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/ee17ba1e827c3f8d19a4d9a6930034c16849fcfe', 'html': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/scoring_offense.csv'}}, 'commit': {'sha': 'd0d733cb7157329024cf3c6a39d3901bcc8bc722', 'node_id': 'C_kwDOP-D23doAKGQwZDczM2NiNzE1NzMyOTAyNGNmM2M2YTM5ZDM5MDFiY2M4YmM3MjI', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/d0d733cb7157329024cf3c6a39d3901bcc8bc722', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/d0d733cb7157329024cf3c6a39d3901bcc8bc722', 'author': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:24Z'}, 'committer': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:24Z'}, 'tree': {'sha': '3607832e7e4c980cbbc3624bd62624c8396fdb96', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/trees/3607832e7e4c980cbbc3624bd62624c8396fdb96'}, 'message': 'Updating scoring_offense table following NFL Week 7', 'parents': [{'sha': 'a230c7fd5f1edf5fe85a108d4208b932a1e60cf2', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/a230c7fd5f1edf5fe85a108d4208b932a1e60cf2', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/a230c7fd5f1edf5fe85a108d4208b932a1e60cf2'}], 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}}
# {'content': {'name': 'scoring_defense.csv', 'path': 'datasets/scoring_defense.csv', 'sha': 'f23bc499e488c5bccf0d9a8972a856f748b07fde', 'size': 3188, 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/scoring_defense.csv?ref=main', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/scoring_defense.csv', 'git_url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/f23bc499e488c5bccf0d9a8972a856f748b07fde', 'download_url': 'https://raw.githubusercontent.com/srmcdevitt03/DS-440-Capstone/main/datasets/scoring_defense.csv', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/scoring_defense.csv?ref=main', 'git': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/f23bc499e488c5bccf0d9a8972a856f748b07fde', 'html': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/scoring_defense.csv'}}, 'commit': {'sha': '2ac2dfe97dd4838c1711129fd1fdb99423f374c0', 'node_id': 'C_kwDOP-D23doAKDJhYzJkZmU5N2RkNDgzOGMxNzExMTI5ZmQxZmRiOTk0MjNmMzc0YzA', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/2ac2dfe97dd4838c1711129fd1fdb99423f374c0', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/2ac2dfe97dd4838c1711129fd1fdb99423f374c0', 'author': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:24Z'}, 'committer': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:24Z'}, 'tree': {'sha': 'c54bb8fc9057d5a8e90ca23b0c37161e82b9b2e5', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/trees/c54bb8fc9057d5a8e90ca23b0c37161e82b9b2e5'}, 'message': 'Updating scoring_defense table following NFL Week 7', 'parents': [{'sha': 'd0d733cb7157329024cf3c6a39d3901bcc8bc722', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/d0d733cb7157329024cf3c6a39d3901bcc8bc722', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/d0d733cb7157329024cf3c6a39d3901bcc8bc722'}], 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}}
# {'content': {'name': 'team_advanced_defense.csv', 'path': 'datasets/team_advanced_defense.csv', 'sha': '850467b74d71647340907c56baefb68136021135', 'size': 2904, 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/team_advanced_defense.csv?ref=main', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/team_advanced_defense.csv', 'git_url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/850467b74d71647340907c56baefb68136021135', 'download_url': 'https://raw.githubusercontent.com/srmcdevitt03/DS-440-Capstone/main/datasets/team_advanced_defense.csv', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/team_advanced_defense.csv?ref=main', 'git': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/850467b74d71647340907c56baefb68136021135', 'html': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/team_advanced_defense.csv'}}, 'commit': {'sha': '813d24217d6dcbadd825c47971368ec4e5a489c2', 'node_id': 'C_kwDOP-D23doAKDgxM2QyNDIxN2Q2ZGNiYWRkODI1YzQ3OTcxMzY4ZWM0ZTVhNDg5YzI', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/813d24217d6dcbadd825c47971368ec4e5a489c2', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/813d24217d6dcbadd825c47971368ec4e5a489c2', 'author': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:25Z'}, 'committer': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:25Z'}, 'tree': {'sha': 'a9c0b9590ada10c28911a58301a16e97a0e7debc', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/trees/a9c0b9590ada10c28911a58301a16e97a0e7debc'}, 'message': 'Updating team_advanced_defense table following NFL Week 7', 'parents': [{'sha': '2ac2dfe97dd4838c1711129fd1fdb99423f374c0', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/2ac2dfe97dd4838c1711129fd1fdb99423f374c0', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/2ac2dfe97dd4838c1711129fd1fdb99423f374c0'}], 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}}
# {'content': {'name': 'team_defense.csv', 'path': 'datasets/team_defense.csv', 'sha': '3256206e081d0e412d6a7de202c2f0a75cf5687a', 'size': 5723, 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/team_defense.csv?ref=main', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/team_defense.csv', 'git_url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/3256206e081d0e412d6a7de202c2f0a75cf5687a', 'download_url': 'https://raw.githubusercontent.com/srmcdevitt03/DS-440-Capstone/main/datasets/team_defense.csv', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/team_defense.csv?ref=main', 'git': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/3256206e081d0e412d6a7de202c2f0a75cf5687a', 'html': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/team_defense.csv'}}, 'commit': {'sha': '389d0d9e416d8947d0b5fca599442a6783962271', 'node_id': 'C_kwDOP-D23doAKDM4OWQwZDllNDE2ZDg5NDdkMGI1ZmNhNTk5NDQyYTY3ODM5NjIyNzE', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/389d0d9e416d8947d0b5fca599442a6783962271', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/389d0d9e416d8947d0b5fca599442a6783962271', 'author': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:25Z'}, 'committer': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:25Z'}, 'tree': {'sha': '3c0c3d778538c5642f63f2513c2dfe6ad6eeff13', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/trees/3c0c3d778538c5642f63f2513c2dfe6ad6eeff13'}, 'message': 'Updating team_defense table following NFL Week 7', 'parents': [{'sha': '813d24217d6dcbadd825c47971368ec4e5a489c2', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/813d24217d6dcbadd825c47971368ec4e5a489c2', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/813d24217d6dcbadd825c47971368ec4e5a489c2'}], 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}}
# {'content': {'name': 'team_offense.csv', 'path': 'datasets/team_offense.csv', 'sha': '41043f0369b34319fb40c87b24042a928bd94265', 'size': 5594, 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/team_offense.csv?ref=main', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/team_offense.csv', 'git_url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/41043f0369b34319fb40c87b24042a928bd94265', 'download_url': 'https://raw.githubusercontent.com/srmcdevitt03/DS-440-Capstone/main/datasets/team_offense.csv', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/team_offense.csv?ref=main', 'git': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/41043f0369b34319fb40c87b24042a928bd94265', 'html': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/team_offense.csv'}}, 'commit': {'sha': '2cf2ca7ac02ed89b1cc225555a430842f5b963c3', 'node_id': 'C_kwDOP-D23doAKDJjZjJjYTdhYzAyZWQ4OWIxY2MyMjU1NTVhNDMwODQyZjViOTYzYzM', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/2cf2ca7ac02ed89b1cc225555a430842f5b963c3', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/2cf2ca7ac02ed89b1cc225555a430842f5b963c3', 'author': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:26Z'}, 'committer': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:26Z'}, 'tree': {'sha': '80e19c8dc1b494c68034849480ac30f1a3cc6644', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/trees/80e19c8dc1b494c68034849480ac30f1a3cc6644'}, 'message': 'Updating team_offense table following NFL Week 7', 'parents': [{'sha': '389d0d9e416d8947d0b5fca599442a6783962271', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/389d0d9e416d8947d0b5fca599442a6783962271', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/389d0d9e416d8947d0b5fca599442a6783962271'}], 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}}
# {'content': {'name': 'master_nfl_data.csv', 'path': 'datasets/master_nfl_data.csv', 'sha': '53f817c64cd22c25c2420785116cfebfd94abcce', 'size': 41970, 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/master_nfl_data.csv?ref=main', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/master_nfl_data.csv', 'git_url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/53f817c64cd22c25c2420785116cfebfd94abcce', 'download_url': 'https://raw.githubusercontent.com/srmcdevitt03/DS-440-Capstone/main/datasets/master_nfl_data.csv', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/contents/datasets/master_nfl_data.csv?ref=main', 'git': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/blobs/53f817c64cd22c25c2420785116cfebfd94abcce', 'html': 'https://github.com/srmcdevitt03/DS-440-Capstone/blob/main/datasets/master_nfl_data.csv'}}, 'commit': {'sha': '930931325265513fb86551a193e0d33f19a957ef', 'node_id': 'C_kwDOP-D23doAKDkzMDkzMTMyNTI2NTUxM2ZiODY1NTFhMTkzZTBkMzNmMTlhOTU3ZWY', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/930931325265513fb86551a193e0d33f19a957ef', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/930931325265513fb86551a193e0d33f19a957ef', 'author': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:27Z'}, 'committer': {'name': 'srmcdevitt03', 'email': '119536826+srmcdevitt03@users.noreply.github.com', 'date': '2025-10-21T18:05:27Z'}, 'tree': {'sha': '26515ca90ab2843a6e182fc3175655e2f23a1b4e', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/trees/26515ca90ab2843a6e182fc3175655e2f23a1b4e'}, 'message': 'Updating master_nfl_data table following NFL Week 7', 'parents': [{'sha': '2cf2ca7ac02ed89b1cc225555a430842f5b963c3', 'url': 'https://api.github.com/repos/srmcdevitt03/DS-440-Capstone/git/commits/2cf2ca7ac02ed89b1cc225555a430842f5b963c3', 'html_url': 'https://github.com/srmcdevitt03/DS-440-Capstone/commit/2cf2ca7ac02ed89b1cc225555a430842f5b963c3'}], 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}}
